# %%
## TFM_01_scrapping_data.ipynb

# %%
import datetime
import timedelta
import os
from typing import List, Dict, Tuple, Any, Union
import pandas as pd
import asyncio
import aiohttp
import pytz
from IPython.display import display

# %%
URL_BASE_BINANCE = "https://api.binance.com/api/v3"
DIRECTORIO_SALIDA = 'binance_data'

# %%
def funcion_definir_ayer():

    zona_utc = pytz.UTC
    hoy_utc = datetime.datetime.now(zona_utc).replace(hour=0, minute=0, second=0, microsecond=0)
    inicio_dia_ayer = hoy_utc - datetime.timedelta(days=1)
    fin_dia_ayer = hoy_utc - datetime.timedelta(microseconds=1)
    
    return inicio_dia_ayer, fin_dia_ayer

# %%
def funcion_calcular_fechas(fecha_texto: str):
    """Calcula fechas de inicio y fin del día."""
    if fecha_texto:
        try:
            fecha_entrada = datetime.datetime.strptime(fecha_texto, '%d/%m/%Y')
            inicio_dia = fecha_entrada.replace(hour=0, minute=0, second=0, microsecond=0)
            fin_dia = fecha_entrada.replace(hour=23, minute=59, second=59, microsecond=999999)
            zona_utc = pytz.UTC
            inicio_dia_utc = zona_utc.localize(inicio_dia)
            fin_dia_utc = zona_utc.localize(fin_dia)
            print(f"Fecha: {inicio_dia_utc.strftime('%Y-%m-%d')}")
            return inicio_dia_utc, fin_dia_utc
        except ValueError:
            print("Formato inválido. Se usará ayer.")
            return funcion_definir_ayer()
    else:
        print("Sin fecha. Se usará ayer.")
        return funcion_definir_ayer()

# %%
async def funcion_obtener_velas_simbolo(sesion: aiohttp.ClientSession, simbolo: str, inicio_dia_utc: datetime.datetime, fin_dia_utc: datetime.datetime):
    """Obtiene velas de Binance para un símbolo y rango de fechas."""
    punto_final = f"{URL_BASE_BINANCE}/klines"
    mitad_dia_utc = inicio_dia_utc + datetime.timedelta(hours=12)

    inicio_ms_1 = int(inicio_dia_utc.timestamp() * 1000)
    fin_ms_1 = int(mitad_dia_utc.timestamp() * 1000) - 1

    inicio_ms_2 = int(mitad_dia_utc.timestamp() * 1000)
    fin_ms_2 = int(fin_dia_utc.timestamp() * 1000)

    todas_velas = []
    simbolo_par = f'{simbolo}USDT'

    parametros_1 = {'symbol': simbolo_par, 'interval': '1m', 'startTime': inicio_ms_1, 'endTime': fin_ms_1, 'limit': 1000}
    parametros_2 = {'symbol': simbolo_par, 'interval': '1m', 'startTime': inicio_ms_2, 'endTime': fin_ms_2, 'limit': 1000}

    try:
        print(f"  Obteniendo primera mitad para {simbolo}...")
        async with sesion.get(punto_final, params=parametros_1) as respuesta_1:
            if respuesta_1.status == 429:
                reintentar_despues = int(respuesta_1.headers.get('Retry-After', 5))
                print(f"  Límite alcanzado {simbolo} (1/2), esperando {reintentar_despues}s")
                await asyncio.sleep(reintentar_despues)
                return await funcion_obtener_velas_simbolo(sesion, simbolo, inicio_dia_utc, fin_dia_utc)

            if respuesta_1.status == 200:
                primera_mitad = await respuesta_1.json()
                todas_velas.extend(primera_mitad)
                print(f"  Primera mitad {simbolo}: {len(primera_mitad)} minutos")
            else:
                error_texto = await respuesta_1.text()
                print(f"  Error en la  primera mitad {simbolo} {respuesta_1.status}, {error_texto}")
                return [], f"Error API {respuesta_1.status} (1/2): {error_texto[:100]}"

        await asyncio.sleep(1)

        print(f"  Obteniendo segunda mitad para {simbolo}...")
        async with sesion.get(punto_final, params=parametros_2) as respuesta_2:
            if respuesta_2.status == 429:
                reintentar_despues = int(respuesta_2.headers.get('Retry-After', 5))
                print(f"  Límite alcanzado {simbolo} (2/2), esperando {reintentar_despues}s")
                await asyncio.sleep(reintentar_despues)
                async with sesion.get(punto_final, params=parametros_2) as respuesta_2_reintento:
                    if respuesta_2_reintento.status == 200:
                        segunda_mitad = await respuesta_2_reintento.json()
                        todas_velas.extend(segunda_mitad)
                        print(f"  Segunda mitad {simbolo} (reintento): {len(segunda_mitad)} minutos")
                    else:
                         error_texto = await respuesta_2_reintento.text()
                         print(f" Error en la segunda mitad {simbolo} (reintento) {respuesta_2_reintento.status}, {error_texto}")

            elif respuesta_2.status == 200:
                segunda_mitad = await respuesta_2.json()
                todas_velas.extend(segunda_mitad)
                print(f"  Segunda mitad {simbolo}: {len(segunda_mitad)} minutos")
            else:
                error_texto = await respuesta_2.text()
                print(f"  Error en la segunda mitad {simbolo} {respuesta_2.status}, {error_texto}")

        minutos_totales = len(todas_velas)
        if minutos_totales == 0 and respuesta_1.status != 200:

             return [], f"Error API {respuesta_1.status} (1/2)"
        elif minutos_totales < 1440:
            print(f"  Datos incompletos {simbolo}. Obtenidos {minutos_totales}/1440 minutos")
            return todas_velas, "Datos Incompletos" 
        else:
            print(f"  Datos completos {simbolo}: {minutos_totales} minutos")
            return todas_velas, "Completo"

    except aiohttp.ClientConnectorError as e:
        print(f"  Error de conexión {simbolo} {str(e)}")
        return [], f"Error de conexión: {str(e)}"
    except Exception as e:
        print(f"  Excepción {simbolo} {str(e)}")
        return [], f"Excepción: {str(e)}"

# %%
def funcion_procesar_velas(velas_crudas: List[Dict], simbolo: str):
    """Procesa velas crudas y retorna un DataFrame."""
    if not velas_crudas:
        return pd.DataFrame(), "Sin datos"

    columnas_df_inicial = [
        'timestamp_ms', 'open', 'high', 'low', 'close', 'volume',
        'close_time_ms', 'quote_asset_volume', 'number_of_trades',
        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'
    ]

    if velas_crudas and len(velas_crudas[0]) != len(columnas_df_inicial):
        print(f"  Columnas inesperadas en {simbolo}.")
        try:
            datos = pd.DataFrame(velas_crudas, columns=columnas_df_inicial)
        except ValueError:
            print(f"  Error al crear DataFrame para {simbolo}.")
            return pd.DataFrame(), "Error de formato"
    else:
        datos = pd.DataFrame(velas_crudas, columns=columnas_df_inicial)

    datos['timestamp'] = pd.to_datetime(datos['timestamp_ms'], unit='ms', utc=True)
    datos['symbol'] = simbolo

    columnas_finales = [
        'timestamp', 'symbol', 'open', 'high', 'low', 'close', 'volume',
        'quote_asset_volume', 'number_of_trades',
        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume'
    ]
    columnas_a_seleccionar = [col for col in columnas_finales if col in datos.columns]
    datos = datos[columnas_a_seleccionar]

    columnas_numericas = [
        'open', 'high', 'low', 'close', 'volume', 'quote_asset_volume',
        'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume'
    ]
    for col in columnas_numericas:
        if col in datos.columns:
            datos[col] = pd.to_numeric(datos[col], errors='coerce')

    columnas_criticas_nan = ['open', 'high', 'low', 'close', 'volume']
    filas_antes = len(datos)
    subset_dropna = [col for col in columnas_criticas_nan if col in datos.columns]
    if subset_dropna:
        datos = datos.dropna(subset=subset_dropna)
    filas_despues = len(datos)
    if filas_antes > filas_despues:
        print(f"  Se eliminaron {filas_antes - filas_despues} filas nulas para {simbolo}.")

    if datos.empty:
        return pd.DataFrame(), "Vacío tras procesar"

    columnas_a_verificar_cero = [
        'quote_asset_volume', 'number_of_trades',
        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume'
    ]
    columnas_con_ceros = []
    for col in columnas_a_verificar_cero:
        if col in datos.columns and (datos[col].fillna(0) == 0).all():
            columnas_con_ceros.append(col)

    if columnas_con_ceros:
        print(f"{simbolo} tiene columnas con solo ceros: {', '.join(columnas_con_ceros)}")
        return datos, f"Valores Cero ({', '.join(columnas_con_ceros)})"

    return datos, "Procesado OK"

# %%
async def funcion_obtener_procesar_lote(lote_simbolos: List[str], inicio_dia_utc: datetime.datetime, fin_dia_utc: datetime.datetime) -> Tuple[List[any], List[dict]]:
    """Obtiene, procesa y agrupa datos de símbolos financieros."""
    lista_dataframes_lote = []
    lista_fallos_lote = []

    async with aiohttp.ClientSession() as sesion:
        tareas = []
        for simbolo in lote_simbolos:
            await asyncio.sleep(0.1)
            tareas.append(asyncio.create_task(funcion_obtener_velas_simbolo(sesion, simbolo, inicio_dia_utc, fin_dia_utc)))

        resultados_crudos = await asyncio.gather(*tareas)

    fecha_str = inicio_dia_utc.strftime('%Y-%m-%d')

    for simbolo, (velas_simbolo, estado_obtencion) in zip(lote_simbolos, resultados_crudos):
        minutos_obtenidos = len(velas_simbolo)

        if not velas_simbolo and estado_obtencion not in ("Completo", "Datos Incompletos"):
            lista_fallos_lote.append({
                'simbolo': simbolo, 'fecha': fecha_str,
                'estado': estado_obtencion,
                'minutos_obtenidos': minutos_obtenidos
            })
            print(f"Omitiendo {simbolo}: {estado_obtencion}")
            continue

        datos_df, estado_procesado = funcion_procesar_velas(velas_simbolo, simbolo)

        if datos_df.empty:

            if not any(f['simbolo'] == simbolo for f in lista_fallos_lote):
                if estado_obtencion in ("Completo", "Datos Incompletos"):
                     lista_fallos_lote.append({
                        'simbolo': simbolo, 'fecha': fecha_str,
                        'estado': estado_procesado,
                        'minutos_obtenidos': minutos_obtenidos
                     })
                else:
                     lista_fallos_lote.append({
                        'simbolo': simbolo, 'fecha': fecha_str,
                        'estado': estado_obtencion,
                        'minutos_obtenidos': minutos_obtenidos
                     })
                print(f"Omitiendo {simbolo}: DataFrame vacío ({estado_procesado}). Obtención: {estado_obtencion}")
            continue

        lista_dataframes_lote.append(datos_df)
        print(f"Procesados {len(datos_df)} registros para {simbolo}")

        if estado_obtencion == "Datos Incompletos":
             lista_fallos_lote.append({
                 'simbolo': simbolo, 'fecha': fecha_str,
                 'estado': estado_obtencion,
                 'minutos_obtenidos': minutos_obtenidos
             })
        elif estado_procesado.startswith("Valores Cero"):
             lista_fallos_lote.append({
                 'simbolo': simbolo, 'fecha': fecha_str,
                 'estado': estado_procesado,
                 'minutos_obtenidos': len(datos_df)
             })

    return lista_dataframes_lote, lista_fallos_lote

# %%
def funcion_guardar_datos(lista_todos_dataframes: List[pd.DataFrame], inicio_dia_utc: datetime.datetime):
    """Guarda datos combinados de DataFrames en un archivo CSV."""
    if not lista_todos_dataframes:
        print("No hay DataFrames válidos.")
        return

    columnas_requeridas = ['timestamp', 'symbol']
    dataframes_validos = []
    for i, df in enumerate(lista_todos_dataframes):
        if all(col in df.columns for col in columnas_requeridas):
            dataframes_validos.append(df)
        else:
            print(f"DataFrame {i} omitido por faltar columnas.")

    if not dataframes_validos:
        print("No hay DataFrames válidos.")
        return

    datos_combinados = pd.concat(dataframes_validos, ignore_index=True)

    if datos_combinados.empty:
        print("DataFrame combinado vacío.")
        return

    fecha_archivo = inicio_dia_utc.strftime('%Y%m%d')
    nombre_archivo = f'datos_binance_minuto_{fecha_archivo}.csv'
    ruta_archivo_salida = os.path.join(DIRECTORIO_SALIDA, nombre_archivo)

    datos_combinados = datos_combinados.sort_values(by=['timestamp', 'symbol'])
    datos_combinados = datos_combinados.drop_duplicates(subset=['timestamp', 'symbol'], keep='last')

    try:
        datos_combinados.to_csv(ruta_archivo_salida, index=False, date_format='%Y-%m-%d %H:%M:%S%z')
        print(f"Datos guardados en {ruta_archivo_salida}. Filas: {len(datos_combinados)}")
    except Exception:
        print(f"Error al guardar el archivo CSV {ruta_archivo_salida}.")

# %%
def funcion_guardar_informe_fallos(lista_todos_fallos: List[Dict], inicio_dia_utc: datetime.datetime):
    """Guarda un informe de fallos en un archivo CSV."""
    if not lista_todos_fallos:
        print("No hubo fallos.")
        return

    datos_fallidos = pd.DataFrame(lista_todos_fallos)
    datos_fallidos = datos_fallidos.sort_values(by=['fecha', 'estado', 'simbolo'])
    datos_fallidos = datos_fallidos.drop_duplicates(subset=['simbolo', 'fecha', 'estado'], keep='last')

    fecha_archivo = inicio_dia_utc.strftime('%Y%m%d')
    nombre_archivo_fallos = f'informe_fallos_{fecha_archivo}.csv'
    ruta_archivo_fallos = os.path.join(DIRECTORIO_SALIDA, nombre_archivo_fallos)

    try:
        datos_fallidos.to_csv(ruta_archivo_fallos, index=False)
        print(f"Informe guardado en {ruta_archivo_fallos}")

        print("\nResumen de problemas:")
        print(f"Total: {len(datos_fallidos)}")
        if not datos_fallidos.empty:
            print("Distribución por estado:")
            print(datos_fallidos['estado'].value_counts().to_string())

    except Exception:
        print(f"Error al guardar el informe en {ruta_archivo_fallos}.")

# %%
async def proceso_principal():
    """Proceso principal para extraer y guardar datos."""
    fecha_entrada_usuario = input("Introduce la fecha (DD/MM/YYYY) o Intro para ayer: ").strip()

    inicio_dia_seleccionado, fin_dia_seleccionado = funcion_calcular_fechas(fecha_entrada_usuario)
    os.makedirs(DIRECTORIO_SALIDA, exist_ok=True)

    lista_simbolos_completa = [
        "1INCH", "AAVE", "ACA", "ACE", "ACH", "ACM", "ADA", "ADX", "AERGO", "AEVO",
        "AGLD", "AI", "AIDOGE", "AKRO", "ALCX", "ALGO", "ALICE", "ALPACA", "ALPHA",
        "ALPINE", "ALT", "AMB", "AMP", "ANKR", "APE", "API3", "APT", "AR", "ARB",
        "ARDR", "ARK", "ARKM", "ARPA", "ASR", "AST", "ASTR", "ATA", "ATH", "ATM",
        "ATOM", "AUCTION", "AUDIO", "AVA", "AVAX", "AXL", "AXS", "BABYDOGE", "BADGER",
        "BAKE", "BAL", "BANANA", "BAND", "BAR", "BAT", "BB", "BCH", "BEAM", "BEL",
        "BETA", "BICO", "BIFI", "BIGTIME", "BLOCK", "BLUR", "BLZ", "BNB", "BNT",
        "BNX", "BOME", "BONE", "BONK", "BRETT", "BSV", "BSW", "BTC", "BURGER", "C98",
        "CAKE", "CELO", "CELR", "CETUS", "CFX", "CHESS", "CHR", "CHZ", "CITY", "CKB",
        "CLV", "COMBO", "COMP", "COS", "COTI", "CRO", "CRV", "CTK", "CTSI", "CTXC",
        "CVC", "CVX", "CYBER", "DAI", "DAR", "DASH", "DATA", "DEGO", "DENT", "DEXE",
        "DF", "DGB", "DIA", "DODO", "DOGE", "DOGS", "DOT", "DUSK", "DYDX", "DYM",
        "EDU", "EGLD", "ELF", "ENA", "ENJ", "ENS", "EOS", "ERN", "ETC", "ETH",
        "ETHFI", "ETHW", "EUR", "FARM", "FET", "FIDA", "FIL", "FIO", "FIS", "FLM",
        "FLOKI", "FLOW", "FLR", "FLUX", "FORTH", "FOXY", "FTM", "FUN", "FXS", "G",
        "GALA", "GAS", "GFT", "GHST", "GLM", "GLMR", "GMT", "GMX", "GNO", "GNS",
        "GPT", "GRT", "GTC", "HARD", "HBAR", "HFT", "HIFI", "HIGH", "HIVE", "HOOK",
        "HOT", "ICP", "ICX", "ID", "IDEX", "ILV", "IMX", "INJ", "IO", "IOST", "IOTX",
        "IQ", "IRIS", "JASMY", "JOE", "JST", "JTO", "JUP", "JUV", "KAS", "KAVA",
        "KDA", "KEY", "KISHU", "KLAY", "KMD", "KNC", "KP3R", "KSM", "LAZIO", "LDO",
        "LEVER", "LINA", "LINK", "LISTA", "LIT", "LOKA", "LOOKS", "LPT", "LQTY",
        "LRC", "LSK", "LTC", "LTO", "LUNA", "LUNC", "MAGIC", "MANA", "MANTA", "MASK",
        "MAV", "MAVIA", "MAX", "MBL", "MBOX", "MDT", "MEME", "MERL", "METIS", "MEW",
        "MINA", "MKR", "MLN", "MNT", "MOVR", "MTL", "MYRO", "NEAR", "NEO", "NEXO",
        "NFP", "NKN", "NMR", "NOT", "NTRN", "NULS", "OAX", "OG", "OGN", "OM", "OMG",
        "OMNI", "ONDO", "ONE", "ONG", "ONT", "OOKI", "OP", "ORBS", "ORDI", "ORN",
        "OSMO", "OXT", "PDA", "PENDLE", "PEOPLE", "PEPE", "PERP", "PHA", "PHB",
        "PIXEL", "POLYX", "POND", "POPCAT", "PORTAL", "PORTO", "POWR", "PRCL", "PROM",
        "PROS", "PSG", "PUNDIX", "PYR", "PYTH", "QI", "QKC", "QNT", "QTUM", "QUICK",
        "RAD", "RARE", "RAY", "RDNT", "REI", "REN", "RENDER", "REQ", "REZ", "RIF",
        "RLC", "RON", "ROSE", "RPL", "RSR", "RUNE", "RVN", "SAFE", "SAGA", "SAND",
        "SANTOS", "SC", "SEI", "SFP", "SHIB", "SKL", "SLF", "SLP", "SNT", "SNX",
        "SOL", "SPELL", "SSV", "STEEM", "STG", "STMX", "STORJ", "STPT", "STRAX",
        "STRK", "STX", "SUI", "SUN", "SUPER", "SUSHI", "SXP", "SYN", "SYS", "T",
        "TAO", "TFUEL", "THETA", "TIA", "TKO", "TLM", "TNSR", "TOKEN", "TON", "TRB",
        "TROY", "TRU", "TRX", "TURBO", "TWT", "UFT", "ULTI", "UMA", "UNFI", "UNI",
        "USD", "USDT", "UTK", "UXLINK", "VANRY", "VENOM", "VET", "VIB", "VIC", "VIDT",
        "VITE", "VOXEL", "VTHO", "W", "WAVES", "WAXP", "WEN", "WIF", "WING", "WLD",
        "WOO", "WRX", "XAI", "XCH", "XEC", "XEM", "XLM", "XMR", "XNO", "XRP", "XTZ",
        "XVG", "XVS", "YFI", "YGG", "ZEC", "ZEN", "ZENT", "ZETA", "ZERO", "ZEUS",
        "ZIL", "ZK", "ZKJ", "ZRO", "ZRX"
    ]

    tamano_lote = 10
    total_lotes = (len(lista_simbolos_completa) + tamano_lote - 1) // tamano_lote

    todos_los_dataframes_finales = []
    todos_los_fallos_finales = []

    for i in range(0, len(lista_simbolos_completa), tamano_lote):
        lote_actual = lista_simbolos_completa[i: i + tamano_lote]
        numero_lote_actual = (i // tamano_lote) + 1

        print(f"\n===== Lote {numero_lote_actual}/{total_lotes} ({', '.join(lote_actual)}) =====")

        dataframes_lote, fallos_lote = await funcion_obtener_procesar_lote(lote_actual, inicio_dia_seleccionado, fin_dia_seleccionado)

        todos_los_dataframes_finales.extend(dataframes_lote)
        todos_los_fallos_finales.extend(fallos_lote)

        tiempo_espera = 3
        print(f"===== Lote {numero_lote_actual} completado. Esperando {tiempo_espera} segundos... =====")
        await asyncio.sleep(tiempo_espera)

    funcion_guardar_datos(todos_los_dataframes_finales, inicio_dia_seleccionado)
    funcion_guardar_informe_fallos(todos_los_fallos_finales, inicio_dia_seleccionado)

    print("\n<<<<< Proceso completado >>>>>")

    fecha_archivo = inicio_dia_seleccionado.strftime('%Y%m%d')
    ruta_datos = os.path.join(DIRECTORIO_SALIDA, f'datos_binance_minuto_{fecha_archivo}.csv')
    ruta_fallos = os.path.join(DIRECTORIO_SALIDA, f'informe_fallos_{fecha_archivo}.csv')
    return ruta_datos, ruta_fallos

# %%
ruta_archivo_datos, ruta_archivo_fallos = await proceso_principal()
# Out:
# Fecha: 2025-03-06
#
# ===== Lote 1/41 (1INCH, AAVE, ACA, ACE, ACH, ACM, ADA, ADX, AERGO, AEVO) =====
#   Obteniendo primera mitad para 1INCH...
#   Obteniendo primera mitad para AAVE...
#   Obteniendo primera mitad para ACA...
#   Obteniendo primera mitad para ACE...
#   Obteniendo primera mitad para ACH...
#   Primera mitad 1INCH: 720 minutos
#   Obteniendo primera mitad para ACM...
#   Primera mitad ACA: 720 minutos
#   Obteniendo primera mitad para ADA...
#   Primera mitad ACE: 720 minutos
#   Obteniendo primera mitad para ADX...
#   Primera mitad AAVE: 720 minutos
#   Primera mitad ACM: 720 minutos
#   Obteniendo primera mitad para AERGO...
#   Primera mitad ACH: 720 minutos
#   Obteniendo primera mitad para AEVO...
#   Primera mitad ADX: 720 minutos
#   Primera mitad AERGO: 720 minutos
#   Primera mitad ADA: 720 minutos
#   Primera mitad AEVO: 720 minutos
#   Obteniendo segunda mitad para 1INCH...
#   Obteniendo segunda mitad para ACE...
#   Obteniendo segunda mitad para ACA...
#   Obteniendo segunda mitad para AAVE...
#   Segunda mitad 1INCH: 720 minutos
#   Datos completos 1INCH: 1440 minutos
#   Obteniendo segunda mitad para ACH...
#   Obteniendo segunda mitad para ACM...
#   Segunda mitad ACA: 720 minutos
#   Datos completos ACA: 1440 minutos
#   Segunda mitad ACE: 720 minutos
#   Datos completos ACE: 1440 minutos
#   Obteniendo segunda mitad para ADX...
#   Segunda mitad AAVE: 720 minutos
#   Datos completos AAVE: 1440 minutos
#   Obteniendo segunda mitad para ADA...
#   Obteniendo segunda mitad para AERGO...
#   Obteniendo segunda mitad para AEVO...
#   Segunda mitad ACM: 720 minutos
#   Datos completos ACM: 1440 minutos
#   Segunda mitad ACH: 720 minutos
#   Datos completos ACH: 1440 minutos
#   Segunda mitad AERGO: 720 minutos
#   Datos completos AERGO: 1440 minutos
#   Segunda mitad ADA: 720 minutos
#   Datos completos ADA: 1440 minutos
#   Segunda mitad ADX: 720 minutos
#   Datos completos ADX: 1440 minutos
#   Segunda mitad AEVO: 720 minutos
#   Datos completos AEVO: 1440 minutos
# Procesados 1440 registros para 1INCH
# Procesados 1440 registros para AAVE
# Procesados 1440 registros para ACA
# Procesados 1440 registros para ACE
# Procesados 1440 registros para ACH
# Procesados 1440 registros para ACM
# Procesados 1440 registros para ADA
# Procesados 1440 registros para ADX
# Procesados 1440 registros para AERGO
# Procesados 1440 registros para AEVO
# ===== Lote 1 completado. Esperando 3 segundos... =====
#
# ===== Lote 2/41 (AGLD, AI, AIDOGE, AKRO, ALCX, ALGO, ALICE, ALPACA, ALPHA, ALPINE) =====
#   Obteniendo primera mitad para AGLD...
#   Obteniendo primera mitad para AI...
#   Obteniendo primera mitad para AIDOGE...
#   Obteniendo primera mitad para AKRO...
#   Obteniendo primera mitad para ALCX...
#   Obteniendo primera mitad para ALGO...
#   Obteniendo primera mitad para ALICE...
#   Obteniendo primera mitad para ALPACA...
#   Error en la  primera mitad AIDOGE 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad AI: 720 minutos
#   Primera mitad AKRO: 0 minutos
#   Obteniendo primera mitad para ALPHA...
#   Primera mitad ALCX: 720 minutos
#   Obteniendo primera mitad para ALPINE...
#   Primera mitad ALICE: 720 minutos
#   Primera mitad ALGO: 720 minutos
#   Primera mitad ALPACA: 720 minutos
#   Primera mitad ALPHA: 720 minutos
#   Primera mitad ALPINE: 720 minutos
#   Primera mitad AGLD: 720 minutos
#   Obteniendo segunda mitad para AKRO...
#   Obteniendo segunda mitad para AI...
#   Obteniendo segunda mitad para ALCX...
#   Segunda mitad AKRO: 0 minutos
#   Datos incompletos AKRO. Obtenidos 0/1440 minutos
#   Segunda mitad AI: 720 minutos
#   Datos completos AI: 1440 minutos
#   Obteniendo segunda mitad para ALICE...
#   Obteniendo segunda mitad para ALGO...
#   Obteniendo segunda mitad para ALPACA...
#   Obteniendo segunda mitad para ALPHA...
#   Segunda mitad ALCX: 720 minutos
#   Datos completos ALCX: 1440 minutos
#   Obteniendo segunda mitad para ALPINE...
#   Segunda mitad ALPHA: 720 minutos
#   Datos completos ALPHA: 1440 minutos
#   Segunda mitad ALGO: 720 minutos
#   Datos completos ALGO: 1440 minutos
#   Segunda mitad ALPACA: 720 minutos
#   Datos completos ALPACA: 1440 minutos
#   Segunda mitad ALICE: 720 minutos
#   Datos completos ALICE: 1440 minutos
#   Obteniendo segunda mitad para AGLD...
#   Segunda mitad ALPINE: 720 minutos
#   Datos completos ALPINE: 1440 minutos
#   Segunda mitad AGLD: 720 minutos
#   Datos completos AGLD: 1440 minutos
# Procesados 1440 registros para AGLD
# Procesados 1440 registros para AI
# Omitiendo AIDOGE: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Omitiendo AKRO: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para ALCX
# Procesados 1440 registros para ALGO
# Procesados 1440 registros para ALICE
# Procesados 1440 registros para ALPACA
# Procesados 1440 registros para ALPHA
# Procesados 1440 registros para ALPINE
# ===== Lote 2 completado. Esperando 3 segundos... =====
#
# ===== Lote 3/41 (ALT, AMB, AMP, ANKR, APE, API3, APT, AR, ARB, ARDR) =====
#   Obteniendo primera mitad para ALT...
#   Obteniendo primera mitad para AMB...
#   Obteniendo primera mitad para AMP...
#   Obteniendo primera mitad para ANKR...
#   Obteniendo primera mitad para APE...
#   Obteniendo primera mitad para API3...
#   Primera mitad ALT: 720 minutos
#   Obteniendo primera mitad para APT...
#   Primera mitad AMP: 720 minutos
#   Primera mitad AMB: 0 minutos
#   Obteniendo primera mitad para AR...
#   Primera mitad ANKR: 720 minutos
#   Primera mitad APE: 720 minutos
#   Primera mitad API3: 720 minutos
#   Obteniendo primera mitad para ARB...
#   Primera mitad APT: 720 minutos
#   Obteniendo primera mitad para ARDR...
#   Primera mitad AR: 720 minutos
#   Primera mitad ARB: 720 minutos
#   Primera mitad ARDR: 720 minutos
#   Obteniendo segunda mitad para ALT...
#   Obteniendo segunda mitad para AMP...
#   Obteniendo segunda mitad para AMB...
#   Obteniendo segunda mitad para ANKR...
#   Obteniendo segunda mitad para APE...
#   Obteniendo segunda mitad para API3...
#   Segunda mitad ALT: 720 minutos
#   Datos completos ALT: 1440 minutos
#   Segunda mitad AMB: 0 minutos
#   Datos incompletos AMB. Obtenidos 0/1440 minutos
#   Obteniendo segunda mitad para APT...
#   Segunda mitad AMP: 720 minutos
#   Datos completos AMP: 1440 minutos
#   Obteniendo segunda mitad para AR...
#   Segunda mitad ANKR: 720 minutos
#   Datos completos ANKR: 1440 minutos
#   Segunda mitad APE: 720 minutos
#   Datos completos APE: 1440 minutos
#   Obteniendo segunda mitad para ARB...
#   Segunda mitad API3: 720 minutos
#   Datos completos API3: 1440 minutos
#   Segunda mitad APT: 720 minutos
#   Datos completos APT: 1440 minutos
#   Obteniendo segunda mitad para ARDR...
#   Segunda mitad AR: 720 minutos
#   Datos completos AR: 1440 minutos
#   Segunda mitad ARB: 720 minutos
#   Datos completos ARB: 1440 minutos
#   Segunda mitad ARDR: 720 minutos
#   Datos completos ARDR: 1440 minutos
# Procesados 1440 registros para ALT
# Omitiendo AMB: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para AMP
# Procesados 1440 registros para ANKR
# Procesados 1440 registros para APE
# Procesados 1440 registros para API3
# Procesados 1440 registros para APT
# Procesados 1440 registros para AR
# Procesados 1440 registros para ARB
# Procesados 1440 registros para ARDR
# ===== Lote 3 completado. Esperando 3 segundos... =====
#
# ===== Lote 4/41 (ARK, ARKM, ARPA, ASR, AST, ASTR, ATA, ATH, ATM, ATOM) =====
#   Obteniendo primera mitad para ARK...
#   Obteniendo primera mitad para ARKM...
#   Obteniendo primera mitad para ARPA...
#   Obteniendo primera mitad para ASR...
#   Obteniendo primera mitad para AST...
#   Primera mitad ARK: 720 minutos
#   Obteniendo primera mitad para ASTR...
#   Primera mitad ARKM: 720 minutos
#   Primera mitad ARPA: 720 minutos
#   Obteniendo primera mitad para ATA...
#   Primera mitad ASR: 720 minutos
#   Obteniendo primera mitad para ATH...
#   Obteniendo primera mitad para ATM...
#   Primera mitad AST: 720 minutos
#   Primera mitad ASTR: 720 minutos
#   Obteniendo primera mitad para ATOM...
#   Primera mitad ATA: 720 minutos
#   Error en la  primera mitad ATH 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad ATM: 720 minutos
#   Primera mitad ATOM: 720 minutos
#   Obteniendo segunda mitad para ARK...
#   Obteniendo segunda mitad para ARKM...
#   Obteniendo segunda mitad para ARPA...
#   Obteniendo segunda mitad para ASR...
#   Segunda mitad ARK: 720 minutos
#   Datos completos ARK: 1440 minutos
#   Obteniendo segunda mitad para AST...
#   Obteniendo segunda mitad para ASTR...
#   Segunda mitad ARKM: 720 minutos
#   Datos completos ARKM: 1440 minutos
#   Obteniendo segunda mitad para ATA...
#   Segunda mitad ARPA: 720 minutos
#   Datos completos ARPA: 1440 minutos
#   Segunda mitad ASR: 720 minutos
#   Datos completos ASR: 1440 minutos
#   Obteniendo segunda mitad para ATM...
#   Segunda mitad ASTR: 720 minutos
#   Datos completos ASTR: 1440 minutos
#   Segunda mitad AST: 720 minutos
#   Datos completos AST: 1440 minutos
#   Obteniendo segunda mitad para ATOM...
#   Segunda mitad ATA: 720 minutos
#   Datos completos ATA: 1440 minutos
#   Segunda mitad ATM: 720 minutos
#   Datos completos ATM: 1440 minutos
#   Segunda mitad ATOM: 720 minutos
#   Datos completos ATOM: 1440 minutos
# Procesados 1440 registros para ARK
# Procesados 1440 registros para ARKM
# Procesados 1440 registros para ARPA
# Procesados 1440 registros para ASR
# Procesados 1440 registros para AST
# Procesados 1440 registros para ASTR
# Procesados 1440 registros para ATA
# Omitiendo ATH: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para ATM
# Procesados 1440 registros para ATOM
# ===== Lote 4 completado. Esperando 3 segundos... =====
#
# ===== Lote 5/41 (AUCTION, AUDIO, AVA, AVAX, AXL, AXS, BABYDOGE, BADGER, BAKE, BAL) =====
#   Obteniendo primera mitad para AUCTION...
#   Obteniendo primera mitad para AUDIO...
#   Obteniendo primera mitad para AVA...
#   Obteniendo primera mitad para AVAX...
#   Obteniendo primera mitad para AXL...
#   Primera mitad AUCTION: 720 minutos
#   Obteniendo primera mitad para AXS...
#   Primera mitad AUDIO: 720 minutos
#   Obteniendo primera mitad para BABYDOGE...
#   Primera mitad AVA: 720 minutos
#   Primera mitad AVAX: 720 minutos
#   Obteniendo primera mitad para BADGER...
#   Obteniendo primera mitad para BAKE...
#   Primera mitad AXS: 720 minutos
#   Primera mitad AXL: 720 minutos
#   Obteniendo primera mitad para BAL...
#   Error en la  primera mitad BABYDOGE 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad BADGER: 720 minutos
#   Primera mitad BAKE: 720 minutos
#   Primera mitad BAL: 720 minutos
#   Obteniendo segunda mitad para AUCTION...
#   Obteniendo segunda mitad para AUDIO...
#   Obteniendo segunda mitad para AVA...
#   Obteniendo segunda mitad para AVAX...
#   Segunda mitad AUCTION: 720 minutos
#   Datos completos AUCTION: 1440 minutos
#   Segunda mitad AUDIO: 720 minutos
#   Datos completos AUDIO: 1440 minutos
#   Obteniendo segunda mitad para AXS...
#   Obteniendo segunda mitad para AXL...
#   Segunda mitad AVAX: 720 minutos
#   Datos completos AVAX: 1440 minutos
#   Segunda mitad AVA: 720 minutos
#   Datos completos AVA: 1440 minutos
#   Obteniendo segunda mitad para BADGER...
#   Obteniendo segunda mitad para BAKE...
#   Segunda mitad AXL: 720 minutos
#   Datos completos AXL: 1440 minutos
#   Segunda mitad AXS: 720 minutos
#   Datos completos AXS: 1440 minutos
#   Obteniendo segunda mitad para BAL...
#   Segunda mitad BAKE: 720 minutos
#   Datos completos BAKE: 1440 minutos
#   Segunda mitad BADGER: 720 minutos
#   Datos completos BADGER: 1440 minutos
#   Segunda mitad BAL: 720 minutos
#   Datos completos BAL: 1440 minutos
# Procesados 1440 registros para AUCTION
# Procesados 1440 registros para AUDIO
# Procesados 1440 registros para AVA
# Procesados 1440 registros para AVAX
# Procesados 1440 registros para AXL
# Procesados 1440 registros para AXS
# Omitiendo BABYDOGE: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para BADGER
# Procesados 1440 registros para BAKE
# Procesados 1440 registros para BAL
# ===== Lote 5 completado. Esperando 3 segundos... =====
#
# ===== Lote 6/41 (BANANA, BAND, BAR, BAT, BB, BCH, BEAM, BEL, BETA, BICO) =====
#   Obteniendo primera mitad para BANANA...
#   Obteniendo primera mitad para BAND...
#   Obteniendo primera mitad para BAR...
#   Obteniendo primera mitad para BAT...
#   Primera mitad BANANA: 720 minutos
#   Obteniendo primera mitad para BB...
#   Primera mitad BAND: 720 minutos
#   Obteniendo primera mitad para BCH...
#   Primera mitad BAR: 720 minutos
#   Obteniendo primera mitad para BEAM...
#   Primera mitad BB: 720 minutos
#   Primera mitad BAT: 720 minutos
#   Obteniendo primera mitad para BEL...
#   Obteniendo primera mitad para BETA...
#   Primera mitad BCH: 720 minutos
#   Primera mitad BEAM: 0 minutos
#   Obteniendo primera mitad para BICO...
#   Primera mitad BEL: 720 minutos
#   Primera mitad BETA: 720 minutos
#   Primera mitad BICO: 720 minutos
#   Obteniendo segunda mitad para BANANA...
#   Obteniendo segunda mitad para BAND...
#   Obteniendo segunda mitad para BAR...
#   Obteniendo segunda mitad para BAT...
#   Obteniendo segunda mitad para BB...
#   Segunda mitad BANANA: 720 minutos
#   Datos completos BANANA: 1440 minutos
#   Obteniendo segunda mitad para BCH...
#   Segunda mitad BAND: 720 minutos
#   Datos completos BAND: 1440 minutos
#   Obteniendo segunda mitad para BEAM...
#   Segunda mitad BAR: 720 minutos
#   Datos completos BAR: 1440 minutos
#   Obteniendo segunda mitad para BEL...
#   Segunda mitad BAT: 720 minutos
#   Datos completos BAT: 1440 minutos
#   Obteniendo segunda mitad para BETA...
#   Segunda mitad BCH: 720 minutos
#   Datos completos BCH: 1440 minutos
#   Segunda mitad BB: 720 minutos
#   Datos completos BB: 1440 minutos
#   Obteniendo segunda mitad para BICO...
#   Segunda mitad BEAM: 0 minutos
#   Datos incompletos BEAM. Obtenidos 0/1440 minutos
#   Segunda mitad BEL: 720 minutos
#   Datos completos BEL: 1440 minutos
#   Segunda mitad BETA: 720 minutos
#   Datos completos BETA: 1440 minutos
#   Segunda mitad BICO: 720 minutos
#   Datos completos BICO: 1440 minutos
# Procesados 1440 registros para BANANA
# Procesados 1440 registros para BAND
# Procesados 1440 registros para BAR
# Procesados 1440 registros para BAT
# Procesados 1440 registros para BB
# Procesados 1440 registros para BCH
# Omitiendo BEAM: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para BEL
# Procesados 1440 registros para BETA
# Procesados 1440 registros para BICO
# ===== Lote 6 completado. Esperando 3 segundos... =====
#
# ===== Lote 7/41 (BIFI, BIGTIME, BLOCK, BLUR, BLZ, BNB, BNT, BNX, BOME, BONE) =====
#   Obteniendo primera mitad para BIFI...
#   Obteniendo primera mitad para BIGTIME...
#   Obteniendo primera mitad para BLOCK...
#   Obteniendo primera mitad para BLUR...
#   Primera mitad BIFI: 720 minutos
#   Obteniendo primera mitad para BLZ...
#   Error en la  primera mitad BIGTIME 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo primera mitad para BNB...
#   Error en la  primera mitad BLOCK 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo primera mitad para BNT...
#   Primera mitad BLZ: 0 minutos
#   Obteniendo primera mitad para BNX...
#   Primera mitad BLUR: 720 minutos
#   Obteniendo primera mitad para BOME...
#   Primera mitad BNB: 720 minutos
#   Obteniendo primera mitad para BONE...
#   Primera mitad BNT: 720 minutos
#   Primera mitad BNX: 720 minutos
#   Primera mitad BOME: 720 minutos
#   Error en la  primera mitad BONE 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo segunda mitad para BIFI...
#   Obteniendo segunda mitad para BLZ...
#   Obteniendo segunda mitad para BLUR...
#   Obteniendo segunda mitad para BNB...
#   Obteniendo segunda mitad para BNT...
#   Segunda mitad BIFI: 720 minutos
#   Datos completos BIFI: 1440 minutos
#   Obteniendo segunda mitad para BNX...
#   Segunda mitad BLUR: 720 minutos
#   Datos completos BLUR: 1440 minutos
#   Segunda mitad BLZ: 0 minutos
#   Datos incompletos BLZ. Obtenidos 0/1440 minutos
#   Obteniendo segunda mitad para BOME...
#   Segunda mitad BNB: 720 minutos
#   Datos completos BNB: 1440 minutos
#   Segunda mitad BNX: 720 minutos
#   Datos completos BNX: 1440 minutos
#   Segunda mitad BNT: 720 minutos
#   Datos completos BNT: 1440 minutos
#   Segunda mitad BOME: 720 minutos
#   Datos completos BOME: 1440 minutos
# Procesados 1440 registros para BIFI
# Omitiendo BIGTIME: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Omitiendo BLOCK: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para BLUR
# Omitiendo BLZ: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para BNB
# Procesados 1440 registros para BNT
# Procesados 1440 registros para BNX
# Procesados 1440 registros para BOME
# Omitiendo BONE: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# ===== Lote 7 completado. Esperando 3 segundos... =====
#
# ===== Lote 8/41 (BONK, BRETT, BSV, BSW, BTC, BURGER, C98, CAKE, CELO, CELR) =====
#   Obteniendo primera mitad para BONK...
#   Obteniendo primera mitad para BRETT...
#   Obteniendo primera mitad para BSV...
#   Obteniendo primera mitad para BSW...
#   Primera mitad BONK: 720 minutos
#   Obteniendo primera mitad para BTC...
#   Error en la  primera mitad BRETT 400, {"code":-1121,"msg":"Invalid symbol."}
#   Error en la  primera mitad BSV 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo primera mitad para BURGER...
#   Obteniendo primera mitad para C98...
#   Primera mitad BSW: 720 minutos
#   Primera mitad BTC: 720 minutos
#   Obteniendo primera mitad para CAKE...
#   Primera mitad BURGER: 720 minutos
#   Obteniendo primera mitad para CELO...
#   Primera mitad C98: 720 minutos
#   Obteniendo primera mitad para CELR...
#   Primera mitad CAKE: 720 minutos
#   Primera mitad CELO: 720 minutos
#   Primera mitad CELR: 720 minutos
#   Obteniendo segunda mitad para BONK...
#   Segunda mitad BONK: 720 minutos
#   Datos completos BONK: 1440 minutos
#   Obteniendo segunda mitad para BSW...
#   Obteniendo segunda mitad para BTC...
#   Obteniendo segunda mitad para BURGER...
#   Obteniendo segunda mitad para C98...
#   Segunda mitad BSW: 720 minutos
#   Datos completos BSW: 1440 minutos
#   Segunda mitad BTC: 720 minutos
#   Datos completos BTC: 1440 minutos
#   Obteniendo segunda mitad para CAKE...
#   Obteniendo segunda mitad para CELO...
#   Segunda mitad BURGER: 720 minutos
#   Datos completos BURGER: 1440 minutos
#   Segunda mitad C98: 720 minutos
#   Datos completos C98: 1440 minutos
#   Obteniendo segunda mitad para CELR...
#   Segunda mitad CAKE: 720 minutos
#   Datos completos CAKE: 1440 minutos
#   Segunda mitad CELO: 720 minutos
#   Datos completos CELO: 1440 minutos
#   Segunda mitad CELR: 720 minutos
#   Datos completos CELR: 1440 minutos
# Procesados 1440 registros para BONK
# Omitiendo BRETT: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Omitiendo BSV: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para BSW
# Procesados 1440 registros para BTC
# Procesados 1440 registros para BURGER
# Procesados 1440 registros para C98
# Procesados 1440 registros para CAKE
# Procesados 1440 registros para CELO
# Procesados 1440 registros para CELR
# ===== Lote 8 completado. Esperando 3 segundos... =====
#
# ===== Lote 9/41 (CETUS, CFX, CHESS, CHR, CHZ, CITY, CKB, CLV, COMBO, COMP) =====
#   Obteniendo primera mitad para CETUS...
#   Obteniendo primera mitad para CFX...
#   Obteniendo primera mitad para CHESS...
#   Obteniendo primera mitad para CHR...
#   Obteniendo primera mitad para CHZ...
#   Primera mitad CFX: 720 minutos
#   Obteniendo primera mitad para CITY...
#   Primera mitad CHESS: 720 minutos
#   Obteniendo primera mitad para CKB...
#   Primera mitad CHR: 720 minutos
#   Obteniendo primera mitad para CLV...
#   Primera mitad CITY: 720 minutos
#   Obteniendo primera mitad para COMBO...
#   Primera mitad CHZ: 720 minutos
#   Obteniendo primera mitad para COMP...
#   Primera mitad CKB: 720 minutos
#   Primera mitad CLV: 0 minutos
#   Primera mitad CETUS: 720 minutos
#   Primera mitad COMBO: 720 minutos
#   Primera mitad COMP: 720 minutos
#   Obteniendo segunda mitad para CFX...
#   Obteniendo segunda mitad para CHESS...
#   Obteniendo segunda mitad para CHR...
#   Obteniendo segunda mitad para CITY...
#   Segunda mitad CFX: 720 minutos
#   Datos completos CFX: 1440 minutos
#   Obteniendo segunda mitad para CHZ...
#   Segunda mitad CHESS: 720 minutos
#   Datos completos CHESS: 1440 minutos
#   Obteniendo segunda mitad para CKB...
#   Segunda mitad CHR: 720 minutos
#   Datos completos CHR: 1440 minutos
#   Obteniendo segunda mitad para CLV...
#   Segunda mitad CITY: 720 minutos
#   Datos completos CITY: 1440 minutos
#   Obteniendo segunda mitad para COMBO...
#   Obteniendo segunda mitad para CETUS...
#   Segunda mitad CHZ: 720 minutos
#   Datos completos CHZ: 1440 minutos
#   Obteniendo segunda mitad para COMP...
#   Segunda mitad CKB: 720 minutos
#   Datos completos CKB: 1440 minutos
#   Segunda mitad CLV: 0 minutos
#   Datos incompletos CLV. Obtenidos 0/1440 minutos
#   Segunda mitad CETUS: 720 minutos
#   Datos completos CETUS: 1440 minutos
#   Segunda mitad COMBO: 720 minutos
#   Datos completos COMBO: 1440 minutos
#   Segunda mitad COMP: 720 minutos
#   Datos completos COMP: 1440 minutos
# Procesados 1440 registros para CETUS
# Procesados 1440 registros para CFX
# Procesados 1440 registros para CHESS
# Procesados 1440 registros para CHR
# Procesados 1440 registros para CHZ
# Procesados 1440 registros para CITY
# Procesados 1440 registros para CKB
# Omitiendo CLV: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para COMBO
# Procesados 1440 registros para COMP
# ===== Lote 9 completado. Esperando 3 segundos... =====
#
# ===== Lote 10/41 (COS, COTI, CRO, CRV, CTK, CTSI, CTXC, CVC, CVX, CYBER) =====
#   Obteniendo primera mitad para COS...
#   Obteniendo primera mitad para COTI...
#   Obteniendo primera mitad para CRO...
#   Obteniendo primera mitad para CRV...
#   Obteniendo primera mitad para CTK...
#   Obteniendo primera mitad para CTSI...
#   Primera mitad COTI: 720 minutos
#   Primera mitad COS: 720 minutos
#   Obteniendo primera mitad para CTXC...
#   Error en la  primera mitad CRO 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo primera mitad para CVC...
#   Primera mitad CRV: 720 minutos
#   Primera mitad CTK: 720 minutos
#   Obteniendo primera mitad para CVX...
#   Obteniendo primera mitad para CYBER...
#   Primera mitad CTXC: 720 minutos
#   Primera mitad CTSI: 720 minutos
#   Primera mitad CVC: 720 minutos
#   Primera mitad CVX: 720 minutos
#   Primera mitad CYBER: 720 minutos
#   Obteniendo segunda mitad para COTI...
#   Obteniendo segunda mitad para COS...
#   Obteniendo segunda mitad para CRV...
#   Obteniendo segunda mitad para CTK...
#   Segunda mitad COS: 720 minutos
#   Datos completos COS: 1440 minutos
#   Segunda mitad COTI: 720 minutos
#   Datos completos COTI: 1440 minutos
#   Obteniendo segunda mitad para CTXC...
#   Obteniendo segunda mitad para CTSI...
#   Obteniendo segunda mitad para CVC...
#   Segunda mitad CRV: 720 minutos
#   Datos completos CRV: 1440 minutos
#   Segunda mitad CTK: 720 minutos
#   Datos completos CTK: 1440 minutos
#   Obteniendo segunda mitad para CVX...
#   Obteniendo segunda mitad para CYBER...
#   Segunda mitad CTSI: 720 minutos
#   Datos completos CTSI: 1440 minutos
#   Segunda mitad CTXC: 720 minutos
#   Datos completos CTXC: 1440 minutos
#   Segunda mitad CVC: 720 minutos
#   Datos completos CVC: 1440 minutos
#   Segunda mitad CVX: 720 minutos
#   Datos completos CVX: 1440 minutos
#   Segunda mitad CYBER: 720 minutos
#   Datos completos CYBER: 1440 minutos
# Procesados 1440 registros para COS
# Procesados 1440 registros para COTI
# Omitiendo CRO: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para CRV
# Procesados 1440 registros para CTK
# Procesados 1440 registros para CTSI
# Procesados 1440 registros para CTXC
# Procesados 1440 registros para CVC
# Procesados 1440 registros para CVX
# Procesados 1440 registros para CYBER
# ===== Lote 10 completado. Esperando 3 segundos... =====
#
# ===== Lote 11/41 (DAI, DAR, DASH, DATA, DEGO, DENT, DEXE, DF, DGB, DIA) =====
#   Obteniendo primera mitad para DAI...
#   Obteniendo primera mitad para DAR...
#   Obteniendo primera mitad para DASH...
#   Obteniendo primera mitad para DATA...
#   Primera mitad DAI: 0 minutos
#   Obteniendo primera mitad para DEGO...
#   Primera mitad DAR: 0 minutos
#   Obteniendo primera mitad para DENT...
#   Primera mitad DASH: 720 minutos
#   Obteniendo primera mitad para DEXE...
#   Primera mitad DATA: 720 minutos
#   Primera mitad DEGO: 720 minutos
#   Obteniendo primera mitad para DF...
#   Primera mitad DENT: 720 minutos
#   Obteniendo primera mitad para DGB...
#   Primera mitad DEXE: 720 minutos
#   Obteniendo primera mitad para DIA...
#   Primera mitad DF: 720 minutos
#   Primera mitad DGB: 720 minutos
#   Obteniendo segunda mitad para DAI...
#   Obteniendo segunda mitad para DAR...
#   Primera mitad DIA: 720 minutos
#   Obteniendo segunda mitad para DASH...
#   Obteniendo segunda mitad para DATA...
#   Obteniendo segunda mitad para DEGO...
#   Segunda mitad DAI: 0 minutos
#   Datos incompletos DAI. Obtenidos 0/1440 minutos
#   Obteniendo segunda mitad para DENT...
#   Segunda mitad DAR: 0 minutos
#   Datos incompletos DAR. Obtenidos 0/1440 minutos
#   Obteniendo segunda mitad para DEXE...
#   Segunda mitad DASH: 720 minutos
#   Datos completos DASH: 1440 minutos
#   Obteniendo segunda mitad para DF...
#   Segunda mitad DATA: 720 minutos
#   Datos completos DATA: 1440 minutos
#   Segunda mitad DEGO: 720 minutos
#   Datos completos DEGO: 1440 minutos
#   Obteniendo segunda mitad para DGB...
#   Segunda mitad DENT: 720 minutos
#   Datos completos DENT: 1440 minutos
#   Segunda mitad DEXE: 720 minutos
#   Datos completos DEXE: 1440 minutos
#   Segunda mitad DF: 720 minutos
#   Datos completos DF: 1440 minutos
#   Obteniendo segunda mitad para DIA...
#   Segunda mitad DGB: 720 minutos
#   Datos completos DGB: 1440 minutos
#   Segunda mitad DIA: 720 minutos
#   Datos completos DIA: 1440 minutos
# Omitiendo DAI: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Omitiendo DAR: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para DASH
# Procesados 1440 registros para DATA
# Procesados 1440 registros para DEGO
# Procesados 1440 registros para DENT
# Procesados 1440 registros para DEXE
# Procesados 1440 registros para DF
# Procesados 1440 registros para DGB
# Procesados 1440 registros para DIA
# ===== Lote 11 completado. Esperando 3 segundos... =====
#
# ===== Lote 12/41 (DODO, DOGE, DOGS, DOT, DUSK, DYDX, DYM, EDU, EGLD, ELF) =====
#   Obteniendo primera mitad para DODO...
#   Obteniendo primera mitad para DOGE...
#   Obteniendo primera mitad para DOGS...
#   Obteniendo primera mitad para DOT...
#   Obteniendo primera mitad para DUSK...
#   Primera mitad DODO: 720 minutos
#   Obteniendo primera mitad para DYDX...
#   Primera mitad DOGS: 720 minutos
#   Primera mitad DOGE: 720 minutos
#   Obteniendo primera mitad para DYM...
#   Obteniendo primera mitad para EDU...
#   Primera mitad DUSK: 720 minutos
#   Primera mitad DYDX: 720 minutos
#   Obteniendo primera mitad para EGLD...
#   Primera mitad DYM: 720 minutos
#   Primera mitad DOT: 720 minutos
#   Obteniendo primera mitad para ELF...
#   Primera mitad EDU: 720 minutos
#   Primera mitad ELF: 720 minutos
#   Obteniendo segunda mitad para DODO...
#   Primera mitad EGLD: 720 minutos
#   Obteniendo segunda mitad para DOGS...
#   Obteniendo segunda mitad para DOGE...
#   Segunda mitad DODO: 720 minutos
#   Datos completos DODO: 1440 minutos
#   Obteniendo segunda mitad para DUSK...
#   Obteniendo segunda mitad para DYDX...
#   Segunda mitad DOGE: 720 minutos
#   Datos completos DOGE: 1440 minutos
#   Obteniendo segunda mitad para DYM...
#   Obteniendo segunda mitad para DOT...
#   Obteniendo segunda mitad para EDU...
#   Segunda mitad DYDX: 720 minutos
#   Datos completos DYDX: 1440 minutos
#   Segunda mitad DUSK: 720 minutos
#   Datos completos DUSK: 1440 minutos
#   Obteniendo segunda mitad para ELF...
#   Segunda mitad DYM: 720 minutos
#   Datos completos DYM: 1440 minutos
#   Segunda mitad DOT: 720 minutos
#   Datos completos DOT: 1440 minutos
#   Obteniendo segunda mitad para EGLD...
#   Segunda mitad EDU: 720 minutos
#   Datos completos EDU: 1440 minutos
#   Segunda mitad DOGS: 720 minutos
#   Datos completos DOGS: 1440 minutos
#   Segunda mitad ELF: 720 minutos
#   Datos completos ELF: 1440 minutos
#   Segunda mitad EGLD: 720 minutos
#   Datos completos EGLD: 1440 minutos
# Procesados 1440 registros para DODO
# Procesados 1440 registros para DOGE
# Procesados 1440 registros para DOGS
# Procesados 1440 registros para DOT
# Procesados 1440 registros para DUSK
# Procesados 1440 registros para DYDX
# Procesados 1440 registros para DYM
# Procesados 1440 registros para EDU
# Procesados 1440 registros para EGLD
# Procesados 1440 registros para ELF
# ===== Lote 12 completado. Esperando 3 segundos... =====
#
# ===== Lote 13/41 (ENA, ENJ, ENS, EOS, ERN, ETC, ETH, ETHFI, ETHW, EUR) =====
#   Obteniendo primera mitad para ENA...
#   Obteniendo primera mitad para ENJ...
#   Obteniendo primera mitad para ENS...
#   Obteniendo primera mitad para EOS...
#   Obteniendo primera mitad para ERN...
#   Primera mitad ENA: 720 minutos
#   Obteniendo primera mitad para ETC...
#   Primera mitad ENJ: 720 minutos
#   Obteniendo primera mitad para ETH...
#   Obteniendo primera mitad para ETHFI...
#   Primera mitad EOS: 720 minutos
#   Obteniendo primera mitad para ETHW...
#   Primera mitad ETC: 720 minutos
#   Primera mitad ERN: 720 minutos
#   Primera mitad ENS: 720 minutos
#   Obteniendo primera mitad para EUR...
#   Primera mitad ETH: 720 minutos
#   Primera mitad ETHFI: 720 minutos
#   Error en la  primera mitad ETHW 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad EUR: 720 minutos
#   Obteniendo segunda mitad para ENA...
#   Obteniendo segunda mitad para ENJ...
#   Segunda mitad ENA: 720 minutos
#   Datos completos ENA: 1440 minutos
#   Obteniendo segunda mitad para EOS...
#   Obteniendo segunda mitad para ETC...
#   Obteniendo segunda mitad para ERN...
#   Obteniendo segunda mitad para ENS...
#   Obteniendo segunda mitad para ETH...
#   Obteniendo segunda mitad para ETHFI...
#   Segunda mitad EOS: 720 minutos
#   Datos completos EOS: 1440 minutos
#   Segunda mitad ENJ: 720 minutos
#   Datos completos ENJ: 1440 minutos
#   Segunda mitad ETC: 720 minutos
#   Datos completos ETC: 1440 minutos
#   Segunda mitad ENS: 720 minutos
#   Datos completos ENS: 1440 minutos
#   Segunda mitad ERN: 720 minutos
#   Datos completos ERN: 1440 minutos
#   Obteniendo segunda mitad para EUR...
#   Segunda mitad ETH: 720 minutos
#   Datos completos ETH: 1440 minutos
#   Segunda mitad ETHFI: 720 minutos
#   Datos completos ETHFI: 1440 minutos
#   Segunda mitad EUR: 720 minutos
#   Datos completos EUR: 1440 minutos
# Procesados 1440 registros para ENA
# Procesados 1440 registros para ENJ
# Procesados 1440 registros para ENS
# Procesados 1440 registros para EOS
# Procesados 1440 registros para ERN
# Procesados 1440 registros para ETC
# Procesados 1440 registros para ETH
# Procesados 1440 registros para ETHFI
# Omitiendo ETHW: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para EUR
# ===== Lote 13 completado. Esperando 3 segundos... =====
#
# ===== Lote 14/41 (FARM, FET, FIDA, FIL, FIO, FIS, FLM, FLOKI, FLOW, FLR) =====
#   Obteniendo primera mitad para FARM...
#   Obteniendo primera mitad para FET...
#   Obteniendo primera mitad para FIDA...
#   Obteniendo primera mitad para FIL...
#   Primera mitad FARM: 720 minutos
#   Obteniendo primera mitad para FIO...
#   Primera mitad FET: 720 minutos
#   Obteniendo primera mitad para FIS...
#   Primera mitad FIDA: 720 minutos
#   Obteniendo primera mitad para FLM...
#   Primera mitad FIL: 720 minutos
#   Primera mitad FIO: 720 minutos
#   Obteniendo primera mitad para FLOKI...
#   Primera mitad FIS: 720 minutos
#   Obteniendo primera mitad para FLOW...
#   Primera mitad FLM: 720 minutos
#   Obteniendo primera mitad para FLR...
#   Primera mitad FLOKI: 720 minutos
#   Primera mitad FLOW: 720 minutos
#   Error en la  primera mitad FLR 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo segunda mitad para FARM...
#   Obteniendo segunda mitad para FET...
#   Obteniendo segunda mitad para FIDA...
#   Obteniendo segunda mitad para FIL...
#   Obteniendo segunda mitad para FIO...
#   Segunda mitad FARM: 720 minutos
#   Datos completos FARM: 1440 minutos
#   Obteniendo segunda mitad para FIS...
#   Obteniendo segunda mitad para FLM...
#   Obteniendo segunda mitad para FLOKI...
#   Segunda mitad FET: 720 minutos
#   Datos completos FET: 1440 minutos
#   Segunda mitad FIDA: 720 minutos
#   Datos completos FIDA: 1440 minutos
#   Segunda mitad FIL: 720 minutos
#   Datos completos FIL: 1440 minutos
#   Obteniendo segunda mitad para FLOW...
#   Segunda mitad FIS: 720 minutos
#   Datos completos FIS: 1440 minutos
#   Segunda mitad FIO: 720 minutos
#   Datos completos FIO: 1440 minutos
#   Segunda mitad FLM: 720 minutos
#   Datos completos FLM: 1440 minutos
#   Segunda mitad FLOW: 720 minutos
#   Datos completos FLOW: 1440 minutos
#   Segunda mitad FLOKI: 720 minutos
#   Datos completos FLOKI: 1440 minutos
# Procesados 1440 registros para FARM
# Procesados 1440 registros para FET
# Procesados 1440 registros para FIDA
# Procesados 1440 registros para FIL
# Procesados 1440 registros para FIO
# Procesados 1440 registros para FIS
# Procesados 1440 registros para FLM
# Procesados 1440 registros para FLOKI
# Procesados 1440 registros para FLOW
# Omitiendo FLR: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# ===== Lote 14 completado. Esperando 3 segundos... =====
#
# ===== Lote 15/41 (FLUX, FORTH, FOXY, FTM, FUN, FXS, G, GALA, GAS, GFT) =====
#   Obteniendo primera mitad para FLUX...
#   Obteniendo primera mitad para FORTH...
#   Obteniendo primera mitad para FOXY...
#   Obteniendo primera mitad para FTM...
#   Obteniendo primera mitad para FUN...
#   Obteniendo primera mitad para FXS...
#   Primera mitad FLUX: 720 minutos
#   Primera mitad FORTH: 720 minutos
#   Obteniendo primera mitad para G...
#   Error en la  primera mitad FOXY 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad FTM: 0 minutos
#   Obteniendo primera mitad para GALA...
#   Obteniendo primera mitad para GAS...
#   Primera mitad FUN: 720 minutos
#   Obteniendo primera mitad para GFT...
#   Primera mitad FXS: 720 minutos
#   Primera mitad G: 720 minutos
#   Primera mitad GALA: 720 minutos
#   Primera mitad GAS: 720 minutos
#   Primera mitad GFT: 0 minutos
#   Obteniendo segunda mitad para FLUX...
#   Obteniendo segunda mitad para FORTH...
#   Obteniendo segunda mitad para FTM...
#   Obteniendo segunda mitad para FUN...
#   Segunda mitad FLUX: 720 minutos
#   Datos completos FLUX: 1440 minutos
#   Segunda mitad FORTH: 720 minutos
#   Datos completos FORTH: 1440 minutos
#   Obteniendo segunda mitad para FXS...
#   Obteniendo segunda mitad para G...
#   Obteniendo segunda mitad para GALA...
#   Segunda mitad FTM: 0 minutos
#   Datos incompletos FTM. Obtenidos 0/1440 minutos
#   Obteniendo segunda mitad para GAS...
#   Segunda mitad FUN: 720 minutos
#   Datos completos FUN: 1440 minutos
#   Obteniendo segunda mitad para GFT...
#   Segunda mitad G: 720 minutos
#   Datos completos G: 1440 minutos
#   Segunda mitad FXS: 720 minutos
#   Datos completos FXS: 1440 minutos
#   Segunda mitad GALA: 720 minutos
#   Datos completos GALA: 1440 minutos
#   Segunda mitad GAS: 720 minutos
#   Datos completos GAS: 1440 minutos
#   Segunda mitad GFT: 0 minutos
#   Datos incompletos GFT. Obtenidos 0/1440 minutos
# Procesados 1440 registros para FLUX
# Procesados 1440 registros para FORTH
# Omitiendo FOXY: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Omitiendo FTM: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para FUN
# Procesados 1440 registros para FXS
# Procesados 1440 registros para G
# Procesados 1440 registros para GALA
# Procesados 1440 registros para GAS
# Omitiendo GFT: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# ===== Lote 15 completado. Esperando 3 segundos... =====
#
# ===== Lote 16/41 (GHST, GLM, GLMR, GMT, GMX, GNO, GNS, GPT, GRT, GTC) =====
#   Obteniendo primera mitad para GHST...
#   Obteniendo primera mitad para GLM...
#   Obteniendo primera mitad para GLMR...
#   Obteniendo primera mitad para GMT...
#   Obteniendo primera mitad para GMX...
#   Primera mitad GLM: 720 minutos
#   Primera mitad GHST: 720 minutos
#   Obteniendo primera mitad para GNO...
#   Obteniendo primera mitad para GNS...
#   Obteniendo primera mitad para GPT...
#   Primera mitad GLMR: 720 minutos
#   Primera mitad GMT: 720 minutos
#   Primera mitad GMX: 720 minutos
#   Obteniendo primera mitad para GRT...
#   Primera mitad GNO: 720 minutos
#   Primera mitad GNS: 720 minutos
#   Obteniendo primera mitad para GTC...
#   Error en la  primera mitad GPT 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad GTC: 720 minutos
#   Primera mitad GRT: 720 minutos
#   Obteniendo segunda mitad para GLM...
#   Obteniendo segunda mitad para GHST...
#   Obteniendo segunda mitad para GLMR...
#   Obteniendo segunda mitad para GMT...
#   Obteniendo segunda mitad para GMX...
#   Segunda mitad GHST: 720 minutos
#   Datos completos GHST: 1440 minutos
#   Segunda mitad GLM: 720 minutos
#   Datos completos GLM: 1440 minutos
#   Obteniendo segunda mitad para GNO...
#   Obteniendo segunda mitad para GNS...
#   Segunda mitad GMX: 720 minutos
#   Datos completos GMX: 1440 minutos
#   Segunda mitad GLMR: 720 minutos
#   Datos completos GLMR: 1440 minutos
#   Segunda mitad GMT: 720 minutos
#   Datos completos GMT: 1440 minutos
#   Obteniendo segunda mitad para GTC...
#   Segunda mitad GNS: 720 minutos
#   Datos completos GNS: 1440 minutos
#   Segunda mitad GNO: 720 minutos
#   Datos completos GNO: 1440 minutos
#   Obteniendo segunda mitad para GRT...
#   Segunda mitad GTC: 720 minutos
#   Datos completos GTC: 1440 minutos
#   Segunda mitad GRT: 720 minutos
#   Datos completos GRT: 1440 minutos
# Procesados 1440 registros para GHST
# Procesados 1440 registros para GLM
# Procesados 1440 registros para GLMR
# Procesados 1440 registros para GMT
# Procesados 1440 registros para GMX
# Procesados 1440 registros para GNO
# Procesados 1440 registros para GNS
# Omitiendo GPT: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para GRT
# Procesados 1440 registros para GTC
# ===== Lote 16 completado. Esperando 3 segundos... =====
#
# ===== Lote 17/41 (HARD, HBAR, HFT, HIFI, HIGH, HIVE, HOOK, HOT, ICP, ICX) =====
#   Obteniendo primera mitad para HARD...
#   Obteniendo primera mitad para HBAR...
#   Obteniendo primera mitad para HFT...
#   Obteniendo primera mitad para HIFI...
#   Obteniendo primera mitad para HIGH...
#   Primera mitad HARD: 720 minutos
#   Primera mitad HBAR: 720 minutos
#   Obteniendo primera mitad para HIVE...
#   Primera mitad HFT: 720 minutos
#   Obteniendo primera mitad para HOOK...
#   Obteniendo primera mitad para HOT...
#   Primera mitad HIFI: 720 minutos
#   Primera mitad HIGH: 720 minutos
#   Primera mitad HIVE: 720 minutos
#   Obteniendo primera mitad para ICP...
#   Primera mitad HOOK: 720 minutos
#   Obteniendo primera mitad para ICX...
#   Primera mitad HOT: 720 minutos
#   Primera mitad ICP: 720 minutos
#   Primera mitad ICX: 720 minutos
#   Obteniendo segunda mitad para HARD...
#   Obteniendo segunda mitad para HBAR...
#   Obteniendo segunda mitad para HFT...
#   Segunda mitad HARD: 720 minutos
#   Datos completos HARD: 1440 minutos
#   Segunda mitad HBAR: 720 minutos
#   Datos completos HBAR: 1440 minutos
#   Obteniendo segunda mitad para HIFI...
#   Obteniendo segunda mitad para HIVE...
#   Obteniendo segunda mitad para HIGH...
#   Segunda mitad HFT: 720 minutos
#   Datos completos HFT: 1440 minutos
#   Obteniendo segunda mitad para HOOK...
#   Obteniendo segunda mitad para HOT...
#   Segunda mitad HIVE: 720 minutos
#   Datos completos HIVE: 1440 minutos
#   Segunda mitad HIGH: 720 minutos
#   Datos completos HIGH: 1440 minutos
#   Segunda mitad HIFI: 720 minutos
#   Datos completos HIFI: 1440 minutos
#   Obteniendo segunda mitad para ICP...
#   Segunda mitad HOOK: 720 minutos
#   Datos completos HOOK: 1440 minutos
#   Obteniendo segunda mitad para ICX...
#   Segunda mitad HOT: 720 minutos
#   Datos completos HOT: 1440 minutos
#   Segunda mitad ICP: 720 minutos
#   Datos completos ICP: 1440 minutos
#   Segunda mitad ICX: 720 minutos
#   Datos completos ICX: 1440 minutos
# Procesados 1440 registros para HARD
# Procesados 1440 registros para HBAR
# Procesados 1440 registros para HFT
# Procesados 1440 registros para HIFI
# Procesados 1440 registros para HIGH
# Procesados 1440 registros para HIVE
# Procesados 1440 registros para HOOK
# Procesados 1440 registros para HOT
# Procesados 1440 registros para ICP
# Procesados 1440 registros para ICX
# ===== Lote 17 completado. Esperando 3 segundos... =====
#
# ===== Lote 18/41 (ID, IDEX, ILV, IMX, INJ, IO, IOST, IOTX, IQ, IRIS) =====
#   Obteniendo primera mitad para ID...
#   Obteniendo primera mitad para IDEX...
#   Obteniendo primera mitad para ILV...
#   Obteniendo primera mitad para IMX...
#   Primera mitad ID: 720 minutos
#   Obteniendo primera mitad para INJ...
#   Primera mitad IDEX: 720 minutos
#   Obteniendo primera mitad para IO...
#   Obteniendo primera mitad para IOST...
#   Primera mitad ILV: 720 minutos
#   Primera mitad IMX: 720 minutos
#   Obteniendo primera mitad para IOTX...
#   Primera mitad INJ: 720 minutos
#   Primera mitad IO: 720 minutos
#   Obteniendo primera mitad para IQ...
#   Primera mitad IOST: 720 minutos
#   Obteniendo primera mitad para IRIS...
#   Primera mitad IOTX: 720 minutos
#   Primera mitad IQ: 720 minutos
#   Primera mitad IRIS: 0 minutos
#   Obteniendo segunda mitad para ID...
#   Obteniendo segunda mitad para IDEX...
#   Obteniendo segunda mitad para ILV...
#   Obteniendo segunda mitad para IMX...
#   Segunda mitad ID: 720 minutos
#   Datos completos ID: 1440 minutos
#   Obteniendo segunda mitad para INJ...
#   Segunda mitad IDEX: 720 minutos
#   Datos completos IDEX: 1440 minutos
#   Obteniendo segunda mitad para IO...
#   Obteniendo segunda mitad para IOST...
#   Segunda mitad IMX: 720 minutos
#   Datos completos IMX: 1440 minutos
#   Segunda mitad ILV: 720 minutos
#   Datos completos ILV: 1440 minutos
#   Obteniendo segunda mitad para IOTX...
#   Segunda mitad INJ: 720 minutos
#   Datos completos INJ: 1440 minutos
#   Obteniendo segunda mitad para IQ...
#   Segunda mitad IO: 720 minutos
#   Datos completos IO: 1440 minutos
#   Obteniendo segunda mitad para IRIS...
#   Segunda mitad IOST: 720 minutos
#   Datos completos IOST: 1440 minutos
#   Segunda mitad IOTX: 720 minutos
#   Datos completos IOTX: 1440 minutos
#   Segunda mitad IQ: 720 minutos
#   Datos completos IQ: 1440 minutos
#   Segunda mitad IRIS: 0 minutos
#   Datos incompletos IRIS. Obtenidos 0/1440 minutos
# Procesados 1440 registros para ID
# Procesados 1440 registros para IDEX
# Procesados 1440 registros para ILV
# Procesados 1440 registros para IMX
# Procesados 1440 registros para INJ
# Procesados 1440 registros para IO
# Procesados 1440 registros para IOST
# Procesados 1440 registros para IOTX
# Procesados 1440 registros para IQ
# Omitiendo IRIS: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# ===== Lote 18 completado. Esperando 3 segundos... =====
#
# ===== Lote 19/41 (JASMY, JOE, JST, JTO, JUP, JUV, KAS, KAVA, KDA, KEY) =====
#   Obteniendo primera mitad para JASMY...
#   Obteniendo primera mitad para JOE...
#   Obteniendo primera mitad para JST...
#   Obteniendo primera mitad para JTO...
#   Primera mitad JASMY: 720 minutos
#   Obteniendo primera mitad para JUP...
#   Primera mitad JOE: 720 minutos
#   Obteniendo primera mitad para JUV...
#   Obteniendo primera mitad para KAS...
#   Primera mitad JST: 720 minutos
#   Primera mitad JUP: 720 minutos
#   Obteniendo primera mitad para KAVA...
#   Obteniendo primera mitad para KDA...
#   Primera mitad JUV: 720 minutos
#   Obteniendo primera mitad para KEY...
#   Primera mitad JTO: 720 minutos
#   Error en la  primera mitad KAS 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad KAVA: 720 minutos
#   Primera mitad KDA: 720 minutos
#   Primera mitad KEY: 0 minutos
#   Obteniendo segunda mitad para JASMY...
#   Obteniendo segunda mitad para JOE...
#   Obteniendo segunda mitad para JST...
#   Segunda mitad JASMY: 720 minutos
#   Datos completos JASMY: 1440 minutos
#   Obteniendo segunda mitad para JUP...
#   Obteniendo segunda mitad para JUV...
#   Segunda mitad JOE: 720 minutos
#   Datos completos JOE: 1440 minutos
#   Obteniendo segunda mitad para JTO...
#   Segunda mitad JST: 720 minutos
#   Datos completos JST: 1440 minutos
#   Obteniendo segunda mitad para KAVA...
#   Segunda mitad JUP: 720 minutos
#   Datos completos JUP: 1440 minutos
#   Obteniendo segunda mitad para KDA...
#   Segunda mitad JUV: 720 minutos
#   Datos completos JUV: 1440 minutos
#   Obteniendo segunda mitad para KEY...
#   Segunda mitad JTO: 720 minutos
#   Datos completos JTO: 1440 minutos
#   Segunda mitad KAVA: 720 minutos
#   Datos completos KAVA: 1440 minutos
#   Segunda mitad KDA: 720 minutos
#   Datos completos KDA: 1440 minutos
#   Segunda mitad KEY: 0 minutos
#   Datos incompletos KEY. Obtenidos 0/1440 minutos
# Procesados 1440 registros para JASMY
# Procesados 1440 registros para JOE
# Procesados 1440 registros para JST
# Procesados 1440 registros para JTO
# Procesados 1440 registros para JUP
# Procesados 1440 registros para JUV
# Omitiendo KAS: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para KAVA
# Procesados 1440 registros para KDA
# Omitiendo KEY: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# ===== Lote 19 completado. Esperando 3 segundos... =====
#
# ===== Lote 20/41 (KISHU, KLAY, KMD, KNC, KP3R, KSM, LAZIO, LDO, LEVER, LINA) =====
#   Obteniendo primera mitad para KISHU...
#   Obteniendo primera mitad para KLAY...
#   Obteniendo primera mitad para KMD...
#   Obteniendo primera mitad para KNC...
#   Obteniendo primera mitad para KP3R...
#   Obteniendo primera mitad para KSM...
#   Error en la  primera mitad KISHU 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad KLAY: 0 minutos
#   Obteniendo primera mitad para LAZIO...
#   Primera mitad KMD: 720 minutos
#   Obteniendo primera mitad para LDO...
#   Primera mitad KNC: 720 minutos
#   Primera mitad KP3R: 0 minutos
#   Obteniendo primera mitad para LEVER...
#   Primera mitad KSM: 720 minutos
#   Obteniendo primera mitad para LINA...
#   Primera mitad LAZIO: 720 minutos
#   Primera mitad LEVER: 720 minutos
#   Primera mitad LINA: 720 minutos
#   Primera mitad LDO: 720 minutos
#   Obteniendo segunda mitad para KLAY...
#   Obteniendo segunda mitad para KMD...
#   Obteniendo segunda mitad para KNC...
#   Obteniendo segunda mitad para KP3R...
#   Obteniendo segunda mitad para KSM...
#   Segunda mitad KLAY: 0 minutos
#   Datos incompletos KLAY. Obtenidos 0/1440 minutos
#   Obteniendo segunda mitad para LAZIO...
#   Segunda mitad KMD: 720 minutos
#   Datos completos KMD: 1440 minutos
#   Segunda mitad KP3R: 0 minutos
#   Datos incompletos KP3R. Obtenidos 0/1440 minutos
#   Segunda mitad KNC: 720 minutos
#   Datos completos KNC: 1440 minutos
#   Obteniendo segunda mitad para LEVER...
#   Segunda mitad KSM: 720 minutos
#   Datos completos KSM: 1440 minutos
#   Obteniendo segunda mitad para LINA...
#   Obteniendo segunda mitad para LDO...
#   Segunda mitad LAZIO: 720 minutos
#   Datos completos LAZIO: 1440 minutos
#   Segunda mitad LEVER: 720 minutos
#   Datos completos LEVER: 1440 minutos
#   Segunda mitad LINA: 720 minutos
#   Datos completos LINA: 1440 minutos
#   Segunda mitad LDO: 720 minutos
#   Datos completos LDO: 1440 minutos
# Omitiendo KISHU: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Omitiendo KLAY: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para KMD
# Procesados 1440 registros para KNC
# Omitiendo KP3R: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para KSM
# Procesados 1440 registros para LAZIO
# Procesados 1440 registros para LDO
# Procesados 1440 registros para LEVER
# Procesados 1440 registros para LINA
# ===== Lote 20 completado. Esperando 3 segundos... =====
#
# ===== Lote 21/41 (LINK, LISTA, LIT, LOKA, LOOKS, LPT, LQTY, LRC, LSK, LTC) =====
#   Obteniendo primera mitad para LINK...
#   Obteniendo primera mitad para LISTA...
#   Obteniendo primera mitad para LIT...
#   Obteniendo primera mitad para LOKA...
#   Obteniendo primera mitad para LOOKS...
#   Primera mitad LISTA: 720 minutos
#   Primera mitad LINK: 720 minutos
#   Obteniendo primera mitad para LPT...
#   Obteniendo primera mitad para LQTY...
#   Primera mitad LOKA: 720 minutos
#   Primera mitad LIT: 0 minutos
#   Error en la  primera mitad LOOKS 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo primera mitad para LRC...
#   Obteniendo primera mitad para LSK...
#   Primera mitad LPT: 720 minutos
#   Obteniendo primera mitad para LTC...
#   Primera mitad LQTY: 720 minutos
#   Primera mitad LRC: 720 minutos
#   Primera mitad LSK: 720 minutos
#   Primera mitad LTC: 720 minutos
#   Obteniendo segunda mitad para LISTA...
#   Obteniendo segunda mitad para LINK...
#   Obteniendo segunda mitad para LOKA...
#   Obteniendo segunda mitad para LIT...
#   Segunda mitad LISTA: 720 minutos
#   Datos completos LISTA: 1440 minutos
#   Segunda mitad LINK: 720 minutos
#   Datos completos LINK: 1440 minutos
#   Obteniendo segunda mitad para LPT...
#   Obteniendo segunda mitad para LQTY...
#   Segunda mitad LIT: 0 minutos
# ...
#   Primera mitad TKO: 720 minutos
#   Obteniendo segunda mitad para SUSHI...
#   Obteniendo segunda mitad para SXP...
#   Obteniendo segunda mitad para SYN...
#   Obteniendo segunda mitad para SYS...
#   Obteniendo segunda mitad para T...
#   Segunda mitad SUSHI: 720 minutos
#   Datos completos SUSHI: 1440 minutos
#   Obteniendo segunda mitad para TAO...
#   Segunda mitad SXP: 720 minutos
#   Datos completos SXP: 1440 minutos
#   Obteniendo segunda mitad para TFUEL...
#   Segunda mitad SYN: 720 minutos
#   Datos completos SYN: 1440 minutos
#   Segunda mitad SYS: 720 minutos
#   Datos completos SYS: 1440 minutos
#   Segunda mitad T: 720 minutos
#   Datos completos T: 1440 minutos
#   Obteniendo segunda mitad para THETA...
#   Segunda mitad TAO: 720 minutos
#   Datos completos TAO: 1440 minutos
#   Obteniendo segunda mitad para TIA...
#   Segunda mitad TFUEL: 720 minutos
#   Datos completos TFUEL: 1440 minutos
#   Obteniendo segunda mitad para TKO...
#   Segunda mitad THETA: 720 minutos
#   Datos completos THETA: 1440 minutos
#   Segunda mitad TIA: 720 minutos
#   Datos completos TIA: 1440 minutos
#   Segunda mitad TKO: 720 minutos
#   Datos completos TKO: 1440 minutos
# Procesados 1440 registros para SUSHI
# Procesados 1440 registros para SXP
# Procesados 1440 registros para SYN
# Procesados 1440 registros para SYS
# Procesados 1440 registros para T
# Procesados 1440 registros para TAO
# Procesados 1440 registros para TFUEL
# Procesados 1440 registros para THETA
# Procesados 1440 registros para TIA
# Procesados 1440 registros para TKO
# ===== Lote 34 completado. Esperando 3 segundos... =====
#
# ===== Lote 35/41 (TLM, TNSR, TOKEN, TON, TRB, TROY, TRU, TRX, TURBO, TWT) =====
#   Obteniendo primera mitad para TLM...
#   Obteniendo primera mitad para TNSR...
#   Obteniendo primera mitad para TOKEN...
#   Obteniendo primera mitad para TON...
#   Primera mitad TLM: 720 minutos
#   Obteniendo primera mitad para TRB...
#   Obteniendo primera mitad para TROY...
#   Primera mitad TNSR: 720 minutos
#   Obteniendo primera mitad para TRU...
#   Error en la  primera mitad TOKEN 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad TON: 720 minutos
#   Obteniendo primera mitad para TRX...
#   Primera mitad TRB: 720 minutos
#   Obteniendo primera mitad para TURBO...
#   Primera mitad TROY: 720 minutos
#   Primera mitad TRU: 720 minutos
#   Obteniendo primera mitad para TWT...
#   Primera mitad TURBO: 720 minutos
#   Primera mitad TRX: 720 minutos
#   Primera mitad TWT: 720 minutos
#   Obteniendo segunda mitad para TLM...
#   Obteniendo segunda mitad para TNSR...
#   Obteniendo segunda mitad para TON...
#   Segunda mitad TLM: 720 minutos
#   Datos completos TLM: 1440 minutos
#   Obteniendo segunda mitad para TRB...
#   Segunda mitad TNSR: 720 minutos
#   Datos completos TNSR: 1440 minutos
#   Obteniendo segunda mitad para TROY...
#   Obteniendo segunda mitad para TRU...
#   Segunda mitad TON: 720 minutos
#   Datos completos TON: 1440 minutos
#   Obteniendo segunda mitad para TURBO...
#   Obteniendo segunda mitad para TWT...
#   Obteniendo segunda mitad para TRX...
#   Segunda mitad TROY: 720 minutos
#   Datos completos TROY: 1440 minutos
#   Segunda mitad TRU: 720 minutos
#   Datos completos TRU: 1440 minutos
#   Segunda mitad TRB: 720 minutos
#   Datos completos TRB: 1440 minutos
#   Segunda mitad TURBO: 720 minutos
#   Datos completos TURBO: 1440 minutos
#   Segunda mitad TWT: 720 minutos
#   Datos completos TWT: 1440 minutos
#   Segunda mitad TRX: 720 minutos
#   Datos completos TRX: 1440 minutos
# Procesados 1440 registros para TLM
# Procesados 1440 registros para TNSR
# Omitiendo TOKEN: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para TON
# Procesados 1440 registros para TRB
# Procesados 1440 registros para TROY
# Procesados 1440 registros para TRU
# Procesados 1440 registros para TRX
# Procesados 1440 registros para TURBO
# Procesados 1440 registros para TWT
# ===== Lote 35 completado. Esperando 3 segundos... =====
#
# ===== Lote 36/41 (UFT, ULTI, UMA, UNFI, UNI, USD, USDT, UTK, UXLINK, VANRY) =====
#   Obteniendo primera mitad para UFT...
#   Obteniendo primera mitad para ULTI...
#   Obteniendo primera mitad para UMA...
#   Obteniendo primera mitad para UNFI...
#   Obteniendo primera mitad para UNI...
#   Error en la  primera mitad ULTI 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad UFT: 720 minutos
#   Obteniendo primera mitad para USD...
#   Obteniendo primera mitad para USDT...
#   Primera mitad UMA: 720 minutos
#   Obteniendo primera mitad para UTK...
#   Primera mitad UNI: 720 minutos
#   Obteniendo primera mitad para UXLINK...
#   Error en la  primera mitad USD 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo primera mitad para VANRY...
#   Error en la  primera mitad USDT 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad UTK: 720 minutos
#   Error en la  primera mitad UXLINK 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad UNFI: 0 minutos
#   Obteniendo segunda mitad para UFT...
#   Obteniendo segunda mitad para UMA...
#   Obteniendo segunda mitad para UNI...
#   Segunda mitad UFT: 720 minutos
#   Datos completos UFT: 1440 minutos
#   Primera mitad VANRY: 720 minutos
#   Segunda mitad UMA: 720 minutos
#   Datos completos UMA: 1440 minutos
#   Obteniendo segunda mitad para UTK...
#   Segunda mitad UNI: 720 minutos
#   Datos completos UNI: 1440 minutos
#   Obteniendo segunda mitad para UNFI...
#   Segunda mitad UTK: 720 minutos
#   Datos completos UTK: 1440 minutos
#   Segunda mitad UNFI: 0 minutos
#   Datos incompletos UNFI. Obtenidos 0/1440 minutos
#   Obteniendo segunda mitad para VANRY...
#   Segunda mitad VANRY: 720 minutos
#   Datos completos VANRY: 1440 minutos
# Procesados 1440 registros para UFT
# Omitiendo ULTI: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para UMA
# Omitiendo UNFI: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para UNI
# Omitiendo USD: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Omitiendo USDT: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para UTK
# Omitiendo UXLINK: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para VANRY
# ===== Lote 36 completado. Esperando 3 segundos... =====
#
# ===== Lote 37/41 (VENOM, VET, VIB, VIC, VIDT, VITE, VOXEL, VTHO, W, WAVES) =====
#   Obteniendo primera mitad para VENOM...
#   Obteniendo primera mitad para VET...
#   Obteniendo primera mitad para VIB...
#   Obteniendo primera mitad para VIC...
#   Obteniendo primera mitad para VIDT...
#   Obteniendo primera mitad para VITE...
#   Error en la  primera mitad VENOM 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad VIB: 720 minutos
#   Obteniendo primera mitad para VOXEL...
#   Obteniendo primera mitad para VTHO...
#   Primera mitad VIC: 720 minutos
#   Primera mitad VET: 720 minutos
#   Primera mitad VIDT: 720 minutos
#   Obteniendo primera mitad para W...
#   Primera mitad VITE: 0 minutos
#   Obteniendo primera mitad para WAVES...
#   Primera mitad VTHO: 720 minutos
#   Primera mitad W: 720 minutos
#   Primera mitad WAVES: 0 minutos
#   Obteniendo segunda mitad para VIB...
#   Primera mitad VOXEL: 720 minutos
#   Obteniendo segunda mitad para VIC...
#   Obteniendo segunda mitad para VET...
#   Obteniendo segunda mitad para VIDT...
#   Segunda mitad VIB: 720 minutos
#   Datos completos VIB: 1440 minutos
#   Obteniendo segunda mitad para VITE...
#   Obteniendo segunda mitad para VTHO...
#   Segunda mitad VET: 720 minutos
#   Datos completos VET: 1440 minutos
#   Segunda mitad VIC: 720 minutos
#   Datos completos VIC: 1440 minutos
#   Obteniendo segunda mitad para W...
#   Segunda mitad VIDT: 720 minutos
#   Datos completos VIDT: 1440 minutos
#   Obteniendo segunda mitad para WAVES...
#   Segunda mitad VITE: 0 minutos
#   Datos incompletos VITE. Obtenidos 0/1440 minutos
#   Segunda mitad VTHO: 720 minutos
#   Datos completos VTHO: 1440 minutos
#   Segunda mitad W: 720 minutos
#   Datos completos W: 1440 minutos
#   Segunda mitad WAVES: 0 minutos
#   Datos incompletos WAVES. Obtenidos 0/1440 minutos
#   Obteniendo segunda mitad para VOXEL...
#   Segunda mitad VOXEL: 720 minutos
#   Datos completos VOXEL: 1440 minutos
# Omitiendo VENOM: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para VET
# Procesados 1440 registros para VIB
# Procesados 1440 registros para VIC
# Procesados 1440 registros para VIDT
# Omitiendo VITE: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para VOXEL
# Procesados 1440 registros para VTHO
# Procesados 1440 registros para W
# Omitiendo WAVES: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# ===== Lote 37 completado. Esperando 3 segundos... =====
#
# ===== Lote 38/41 (WAXP, WEN, WIF, WING, WLD, WOO, WRX, XAI, XCH, XEC) =====
#   Obteniendo primera mitad para WAXP...
#   Obteniendo primera mitad para WEN...
#   Obteniendo primera mitad para WIF...
#   Obteniendo primera mitad para WING...
#   Obteniendo primera mitad para WLD...
#   Obteniendo primera mitad para WOO...
#   Error en la  primera mitad WEN 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo primera mitad para WRX...
#   Primera mitad WIF: 720 minutos
#   Obteniendo primera mitad para XAI...
#   Primera mitad WING: 720 minutos
#   Primera mitad WAXP: 720 minutos
#   Primera mitad WLD: 720 minutos
#   Obteniendo primera mitad para XCH...
#   Obteniendo primera mitad para XEC...
#   Primera mitad WRX: 0 minutos
#   Primera mitad WOO: 720 minutos
#   Primera mitad XAI: 720 minutos
#   Error en la  primera mitad XCH 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad XEC: 720 minutos
#   Obteniendo segunda mitad para WIF...
#   Obteniendo segunda mitad para WING...
#   Obteniendo segunda mitad para WAXP...
#   Obteniendo segunda mitad para WLD...
#   Obteniendo segunda mitad para WRX...
#   Obteniendo segunda mitad para WOO...
#   Segunda mitad WIF: 720 minutos
#   Datos completos WIF: 1440 minutos
#   Obteniendo segunda mitad para XAI...
#   Segunda mitad WAXP: 720 minutos
#   Datos completos WAXP: 1440 minutos
#   Segunda mitad WING: 720 minutos
#   Datos completos WING: 1440 minutos
#   Segunda mitad WLD: 720 minutos
#   Datos completos WLD: 1440 minutos
#   Obteniendo segunda mitad para XEC...
#   Segunda mitad WRX: 0 minutos
#   Datos incompletos WRX. Obtenidos 0/1440 minutos
#   Segunda mitad WOO: 720 minutos
#   Datos completos WOO: 1440 minutos
#   Segunda mitad XAI: 720 minutos
#   Datos completos XAI: 1440 minutos
#   Segunda mitad XEC: 720 minutos
#   Datos completos XEC: 1440 minutos
# Procesados 1440 registros para WAXP
# Omitiendo WEN: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para WIF
# Procesados 1440 registros para WING
# Procesados 1440 registros para WLD
# Procesados 1440 registros para WOO
# Omitiendo WRX: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para XAI
# Omitiendo XCH: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para XEC
# ===== Lote 38 completado. Esperando 3 segundos... =====
#
# ===== Lote 39/41 (XEM, XLM, XMR, XNO, XRP, XTZ, XVG, XVS, YFI, YGG) =====
#   Obteniendo primera mitad para XEM...
#   Obteniendo primera mitad para XLM...
#   Obteniendo primera mitad para XMR...
#   Obteniendo primera mitad para XNO...
#   Primera mitad XLM: 720 minutos
#   Primera mitad XEM: 0 minutos
#   Obteniendo primera mitad para XRP...
#   Obteniendo primera mitad para XTZ...
#   Primera mitad XMR: 0 minutos
#   Obteniendo primera mitad para XVG...
#   Primera mitad XNO: 720 minutos
#   Obteniendo primera mitad para XVS...
#   Primera mitad XRP: 720 minutos
#   Obteniendo primera mitad para YFI...
#   Primera mitad XTZ: 720 minutos
#   Obteniendo primera mitad para YGG...
#   Primera mitad XVG: 720 minutos
#   Primera mitad XVS: 720 minutos
#   Primera mitad YFI: 720 minutos
#   Primera mitad YGG: 720 minutos
#   Obteniendo segunda mitad para XEM...
#   Obteniendo segunda mitad para XLM...
#   Obteniendo segunda mitad para XMR...
#   Obteniendo segunda mitad para XRP...
#   Obteniendo segunda mitad para XNO...
#   Segunda mitad XEM: 0 minutos
#   Datos incompletos XEM. Obtenidos 0/1440 minutos
#   Segunda mitad XLM: 720 minutos
#   Datos completos XLM: 1440 minutos
#   Obteniendo segunda mitad para XTZ...
#   Obteniendo segunda mitad para XVG...
#   Segunda mitad XMR: 0 minutos
#   Datos incompletos XMR. Obtenidos 0/1440 minutos
#   Obteniendo segunda mitad para XVS...
#   Segunda mitad XRP: 720 minutos
#   Datos completos XRP: 1440 minutos
#   Obteniendo segunda mitad para YFI...
#   Segunda mitad XNO: 720 minutos
#   Datos completos XNO: 1440 minutos
#   Segunda mitad XTZ: 720 minutos
#   Datos completos XTZ: 1440 minutos
#   Obteniendo segunda mitad para YGG...
#   Segunda mitad XVG: 720 minutos
#   Datos completos XVG: 1440 minutos
#   Segunda mitad XVS: 720 minutos
#   Datos completos XVS: 1440 minutos
#   Segunda mitad YFI: 720 minutos
#   Datos completos YFI: 1440 minutos
#   Segunda mitad YGG: 720 minutos
#   Datos completos YGG: 1440 minutos
# Omitiendo XEM: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para XLM
# Omitiendo XMR: DataFrame vacío (Sin datos). Obtención: Datos Incompletos
# Procesados 1440 registros para XNO
# Procesados 1440 registros para XRP
# Procesados 1440 registros para XTZ
# Procesados 1440 registros para XVG
# Procesados 1440 registros para XVS
# Procesados 1440 registros para YFI
# Procesados 1440 registros para YGG
# ===== Lote 39 completado. Esperando 3 segundos... =====
#
# ===== Lote 40/41 (ZEC, ZEN, ZENT, ZETA, ZERO, ZEUS, ZIL, ZK, ZKJ, ZRO) =====
#   Obteniendo primera mitad para ZEC...
#   Obteniendo primera mitad para ZEN...
#   Obteniendo primera mitad para ZENT...
#   Obteniendo primera mitad para ZETA...
#   Primera mitad ZEC: 720 minutos
#   Obteniendo primera mitad para ZERO...
#   Primera mitad ZEN: 720 minutos
#   Obteniendo primera mitad para ZEUS...
#   Error en la  primera mitad ZENT 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo primera mitad para ZIL...
#   Error en la  primera mitad ZETA 400, {"code":-1121,"msg":"Invalid symbol."}
#   Error en la  primera mitad ZERO 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo primera mitad para ZK...
#   Error en la  primera mitad ZEUS 400, {"code":-1121,"msg":"Invalid symbol."}
#   Obteniendo primera mitad para ZKJ...
#   Primera mitad ZIL: 720 minutos
#   Obteniendo primera mitad para ZRO...
#   Primera mitad ZK: 720 minutos
#   Error en la  primera mitad ZKJ 400, {"code":-1121,"msg":"Invalid symbol."}
#   Primera mitad ZRO: 720 minutos
#   Obteniendo segunda mitad para ZEC...
#   Obteniendo segunda mitad para ZEN...
#   Segunda mitad ZEC: 720 minutos
#   Datos completos ZEC: 1440 minutos
#   Segunda mitad ZEN: 720 minutos
#   Datos completos ZEN: 1440 minutos
#   Obteniendo segunda mitad para ZIL...
#   Obteniendo segunda mitad para ZK...
#   Obteniendo segunda mitad para ZRO...
#   Segunda mitad ZIL: 720 minutos
#   Datos completos ZIL: 1440 minutos
#   Segunda mitad ZK: 720 minutos
#   Datos completos ZK: 1440 minutos
#   Segunda mitad ZRO: 720 minutos
#   Datos completos ZRO: 1440 minutos
# Procesados 1440 registros para ZEC
# Procesados 1440 registros para ZEN
# Omitiendo ZENT: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Omitiendo ZETA: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Omitiendo ZERO: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Omitiendo ZEUS: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para ZIL
# Procesados 1440 registros para ZK
# Omitiendo ZKJ: Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}
# Procesados 1440 registros para ZRO
# ===== Lote 40 completado. Esperando 3 segundos... =====
#
# ===== Lote 41/41 (ZRX) =====
#   Obteniendo primera mitad para ZRX...
#   Primera mitad ZRX: 720 minutos
#   Obteniendo segunda mitad para ZRX...
#   Segunda mitad ZRX: 720 minutos
#   Datos completos ZRX: 1440 minutos
# Procesados 1440 registros para ZRX
# ===== Lote 41 completado. Esperando 3 segundos... =====
# Datos guardados en .\datos_binance_minuto_20250306.csv. Filas: 480960
# Informe guardado en .\informe_fallos_20250306.csv
#
# Resumen de problemas:
# Total: 67
# Distribución por estado:
# estado
# Error API 400 (1/2): {"code":-1121,"msg":"Invalid symbol."}    41
# Sin datos                                                      26
#
# <<<<< Proceso completado >>>>>

# %%
if os.path.exists(ruta_archivo_fallos):
    try:
        df_fallos = pd.read_csv(ruta_archivo_fallos)
        print("\nInforme de Fallos:")
        display(df_fallos)
    except Exception:
        print("No se pudo leer el informe de fallos.")
else:
    print(f"\nInforme de fallos no encontrado: {ruta_archivo_fallos}")
# Out:
# Informe de Fallos:
#      simbolo       fecha                                             estado  \
# 0     AIDOGE  2025-03-06  Error API 400 (1/2): {"code":-1121,"msg":"Inva...
# 1        ATH  2025-03-06  Error API 400 (1/2): {"code":-1121,"msg":"Inva...
# 2   BABYDOGE  2025-03-06  Error API 400 (1/2): {"code":-1121,"msg":"Inva...
# 3    BIGTIME  2025-03-06  Error API 400 (1/2): {"code":-1121,"msg":"Inva...
# 4      BLOCK  2025-03-06  Error API 400 (1/2): {"code":-1121,"msg":"Inva...
# ..       ...         ...                                                ...
# 62      VITE  2025-03-06                                          Sin datos
# 63     WAVES  2025-03-06                                          Sin datos
# 64       WRX  2025-03-06                                          Sin datos
# 65       XEM  2025-03-06                                          Sin datos
# 66       XMR  2025-03-06                                          Sin datos
#
#     minutos_obtenidos
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 62                  0
# 63                  0
# 64                  0
# 65                  0
# 66                  0
#
# [67 rows x 4 columns]

# %%
if os.path.exists(ruta_archivo_datos):
    try:
        df_datos_muestra = pd.read_csv(ruta_archivo_datos, nrows=10)
        print(f"\nMuestra del archivo de datos ({os.path.basename(ruta_archivo_datos)}):")
        display(df_datos_muestra)
    except Exception:
        print("No se pudo leer el archivo de datos.")
else:
    print(f"\nArchivo de datos no encontrado: {ruta_archivo_datos}")
# Out:
# Muestra del archivo de datos (datos_binance_minuto_20250306.csv):
#                   timestamp symbol       open       high        low  \
# 0  2025-03-06 00:00:00+0000  1INCH    0.23400    0.23410    0.23390
# 1  2025-03-06 00:00:00+0000   AAVE  220.91000  221.00000  220.61000
# 2  2025-03-06 00:00:00+0000    ACA    0.04270    0.04270    0.04260
# 3  2025-03-06 00:00:00+0000    ACE    0.79400    0.79600    0.79400
# 4  2025-03-06 00:00:00+0000    ACH    0.02634    0.02634    0.02633
# 5  2025-03-06 00:00:00+0000    ACM    0.96700    0.96800    0.96600
# 6  2025-03-06 00:00:00+0000    ADA    0.97410    0.97580    0.97230
# 7  2025-03-06 00:00:00+0000    ADX    0.11800    0.11810    0.11790
# 8  2025-03-06 00:00:00+0000  AERGO    0.07420    0.07420    0.07420
# 9  2025-03-06 00:00:00+0000   AEVO    0.13680    0.13680    0.13670
#
#        close      volume  quote_asset_volume  number_of_trades  \
# 0    0.23410    8029.000         1878.889200                 9
# 1  220.72000      79.552        17568.970720               211
# 2    0.04270     996.570           42.517375                 4
# 3    0.79600    8102.800         6437.004300                25
# 4    0.02633   12601.000          331.875830                 9
# 5    0.96800     287.900          278.419600                15
# 6    0.97440  668067.600       650840.583750              1798
# 7    0.11810    7395.000          872.329600                12
# 8    0.07420    7800.000          578.760000                 4
# 9    0.13680   17015.220         2326.153446                13
#
#    taker_buy_base_asset_volume  taker_buy_quote_asset_volume
# 0                     5689.000                   1331.563200
# 1                       31.828                   7030.127490
# 2                      634.930                     27.111511
# 3                     8102.800                   6437.004300
# 4                     5378.000                    141.656520
# 5                      153.000                    148.074700
# 6                   277734.500                 270686.237670
# 7                     1323.000                    156.146900
# 8                     7800.000                    578.760000
# 9                     4565.690                    624.239475
